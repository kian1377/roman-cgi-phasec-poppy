# %%
import numpy as np
import cupy as cp
import ray
import astropy.units as u
from IPython.display import clear_output
import time
from pathlib import Path
from matplotlib.patches import Circle

import poppy

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('DEBUG')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

import warnings
warnings.filterwarnings("ignore")

import misc

from poppy_roman_cgi_phasec import cgi

from importlib import reload
import copy

wavelength_c = 825e-9*u.m

nlam = 3
bandwidth = 0.1
minlam = wavelength_c * (1 - bandwidth/2)
maxlam = wavelength_c * (1 + bandwidth/2)
wavelengths = np.linspace( minlam, maxlam, nlam )

iwa = 5.9
owa = 20.1

data_dir = Path('/groups/douglase/kians-data-files/poppy-cupy-tests-data')

# %%
poppy.conf.use_cupy = True
poppy.conf.use_mkl = True
poppy.conf.use_fftw = True

poppy_log.disabled = True

reload(cgi)
spcw = cgi.CGI(cgi_mode='spc-wide', psf_pixelscale_lamD=0.2, npsf=256, use_pupil_defocus=True, use_opds=False)
spcw_opds = cgi.CGI(cgi_mode='spc-wide', psf_pixelscale_lamD=0.2, npsf=256, use_pupil_defocus=True, use_opds=True)

# %% [markdown]
# # Test monochromatic PSFs.

# %%
wf = spcw.calc_psf(quiet=False)

psf_mono = wf.intensity

patches = [Circle((0, 0), iwa, color='c', fill=False), Circle((0, 0), owa, color='c', fill=False)]
misc.myimshow(psf_mono, lognorm=True, pxscl=spcw.psf_pixelscale_lamD, patches=patches, vmin=1e-14)

if isinstance(psf_mono, np.ndarray):
    misc.save_pickle(data_dir/'spcw_cpu_wfs_mono', wf)
else:
    misc.save_pickle(data_dir/'spcw_gpu_wfs_mono', wf)
# Out:
# Propagating wavelength 825.000 nm.
# PSF calculated in 0.347s
# Saved data to:  /groups/douglase/kians-data-files/poppy-cupy-tests-data/spcw_gpu_wfs_mono

# %%
wf = spcw_opds.calc_psf(quiet=False)

psf_mono = wf.intensity

patches = [Circle((0, 0), iwa, color='c', fill=False), Circle((0, 0), owa, color='c', fill=False)]
misc.myimshow(psf_mono, lognorm=True, pxscl=spcw.psf_pixelscale_lamD, patches=patches, vmin=1e-12)

if isinstance(psf_mono, np.ndarray):
    misc.save_pickle(data_dir/'spcw_cpu_wfs_mono_opds', wf)
else:
    misc.save_pickle(data_dir/'spcw_gpu_wfs_mono_opds', wf)
# Out:
# Propagating wavelength 825.000 nm.
# PSF calculated in 0.411s
# Saved data to:  /groups/douglase/kians-data-files/poppy-cupy-tests-data/spcw_gpu_wfs_mono_opds

# %% [markdown]
# # Test broadband PSFs.

# %%
settings = spcw.copy_mode_settings(nlam)
for i,sett in enumerate(settings):
    sett.update({'wavelength':wavelengths[i]})
settings
# Out:
# [{'cgi_mode': 'spc-wide',
#   'wavelength': <Quantity 7.8375e-07 m>,
#   'npsf': 256,
#   'psf_pixelscale': <Quantity 8.58e-06 m / pix>,
#   'interp_order': 3,
#   'offset': (0, 0),
#   'use_fpm': True,
#   'use_fieldstop': False,
#   'use_pupil_defocus': True,
#   'use_opds': False,
#   'polaxis': 0,
#   'return_intermediates': False},
#  {'cgi_mode': 'spc-wide',
#   'wavelength': <Quantity 8.25e-07 m>,
#   'npsf': 256,
#   'psf_pixelscale': <Quantity 8.58e-06 m / pix>,
#   'interp_order': 3,
#   'offset': (0, 0),
#   'use_fpm': True,
#   'use_fieldstop': False,
#   'use_pupil_defocus': True,
#   'use_opds': False,
#   'polaxis': 0,
#   'return_intermediates': False},
#  {'cgi_mode': 'spc-wide',
#   'wavelength': <Quantity 8.6625e-07 m>,
#   'npsf': 256,
#   'psf_pixelscale': <Quantity 8.58e-06 m / pix>,
#   'interp_order': 3,
#   'offset': (0, 0),
#   'use_fpm': True,
#   'use_fieldstop': False,
#   'use_pupil_defocus': True,
#   'use_opds': False,
#   'polaxis': 0,
#   'return_intermediates': False}]

# %%
spcw_actors = cgi.create_actors(ncpus=10, ngpus=1/3, settings=settings)

# %%
reload(cgi)
wfs = cgi.calc_psfs(spcw_actors, quiet=False)
# Out:
# (CGI pid=235740) Propagating wavelength 783.750 nm.
# (CGI pid=235741) Propagating wavelength 825.000 nm.
# (CGI pid=235742) Propagating wavelength 866.250 nm.
# (CGI pid=235740) /home/u21/kianmilani/src/poppy/poppy/geometry.py:215: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
# (CGI pid=235740)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
# (CGI pid=235741) /home/u21/kianmilani/src/poppy/poppy/geometry.py:215: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
# (CGI pid=235741)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
# (CGI pid=235741) /home/u21/kianmilani/src/poppy/poppy/geometry.py:215: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
# (CGI pid=235741)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
# (CGI pid=235740) /home/u21/kianmilani/src/poppy/poppy/geometry.py:215: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
# (CGI pid=235740)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
# (CGI pid=235742) /home/u21/kianmilani/src/poppy/poppy/geometry.py:215: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
# (CGI pid=235742)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
# (CGI pid=235742) /home/u21/kianmilani/src/poppy/poppy/geometry.py:215: UserWarning: filled_circle_aa may not yield exact results for grey pixels when pixel scale <1
# (CGI pid=235742)   warnings.warn('filled_circle_aa may not yield exact results for grey pixels when pixel scale <1')
# (CGI pid=235742) PSF calculated in 0.924s
# (CGI pid=235741) PSF calculated in 0.926s
# (CGI pid=235740) PSF calculated in 0.924s
# All PSFs calculated in 1.024s

# %%
psf_broad = 0
for i in range(nlam):
    psf_broad += wfs[i].intensity/nlam

patches = [Circle((0, 0), iwa, color='c', fill=False), Circle((0, 0), owa, color='c', fill=False)]
misc.myimshow(psf_broad, lognorm=True, pxscl=spcw.psf_pixelscale_lamD, patches=patches, vmin=1e-12)

if isinstance(psf_mono, np.ndarray):
    misc.save_pickle(data_dir/'spcw_cpu_wfs_broad', wf)
else:
    misc.save_pickle(data_dir/'spcw_gpu_wfs_broad', wf)
# Out:
# Saved data to:  /groups/douglase/kians-data-files/poppy-cupy-tests-data/spcw_gpu_wfs_broad
