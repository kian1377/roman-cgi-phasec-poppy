# %%
import numpy as np
import astropy.units as u
from pathlib import Path
from importlib import reload

import poppy
print(poppy.accel_math._NUMEXPR_AVAILABLE)
print(poppy.accel_math._MKLFFT_AVAILABLE)
print(poppy.accel_math._FFTW_AVAILABLE)
print(poppy.accel_math._CUDA_AVAILABLE)
print(poppy.accel_math._OPENCL_AVAILABLE)

# poppy.conf.use_numexpr = True
# poppy.conf.use_fftw = False
# poppy.conf.use_mkl = True
# poppy.conf.use_cuda = False
# poppy.conf.use_opencl = False

import misc
import poppy_roman_cgi_phasec as cgi
from poppy_roman_cgi_phasec import hlc
reload(hlc)

# set debugging mode for more information from POPPY as propagation is performed
import logging, sys
_log = logging.getLogger('poppy')
_log.setLevel("DEBUG")
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

# cgi_dir = Path('C:/Users/Kian/Desktop/roman-cgi-phasec-data')
# cgi_dir = Path('/Users/kianmilani/Desktop/roman-cgi-phasec-data')
cgi_dir = Path('/groups/douglase/kians-data-files/roman-cgi-phasec-data')
# Out:
# True
# True
# False
# False
# False

# %%
reload(hlc)

wavelength = 575e-9*u.m
npsf = 256
psf_pixelscale = 2.9587988e-6*u.m/u.pix
polaxis = 0

psf, wfs = hlc.run_single(wavelength=wavelength,
                           npix=310,
                           oversample=1024/310,
                           npsf=npsf,
                           psf_pixelscale=psf_pixelscale,
#                            offsets=(6,0),
#                            dm1='hlc_dm1.fits', dm2='hlc_dm2.fits',
#                            dm1='hlc_best_contrast_dm1.fits', dm2='hlc_best_contrast_dm2.fits',
                           use_opds=False,
                           use_pupil_defocus=True,
                           use_fieldstop=True,
                           polaxis=polaxis,
                           cgi_dir=cgi_dir,
                           display_mode=False,
                           display_intermediates=False,
                           return_intermediates=True,
                          )

misc.myimshow2(wfs[-1].intensity, wfs[-1].phase, lognorm1=True,
               pxscl1=psf_pixelscale, pxscl2=psf_pixelscale,)
# Out:
# Propagating wavelength 575.000 nm.
# DEBUG:poppy:Trans: /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/pupil.fits
# DEBUG:poppy:OPD: None
# INFO:poppy:Roman Pupil: Loaded amplitude transmission from /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/pupil.fits
# DEBUG:poppy:Trans: /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/lyot_rotated.fits
# DEBUG:poppy:OPD: None
# INFO:poppy:Lyot Stop: Loaded amplitude transmission from /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/lyot_rotated.fits
# DEBUG:poppy:Trans: /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.57500000um_real.fits
# DEBUG:poppy:OPD: None
# INFO:poppy:COMPLEX OCCULTER: Loaded amplitude transmission from /groups/douglase/kians-data-files/roman-cgi-phasec-data/hlc/hlc_fpm_trans_0.57500000um_real.fits
# DEBUG:poppy:FixedSamplingImagePlaneElement COMPLEX OCCULTER initialized:centering style ADJUSTABLE, central wavelength for operation 5.75e-07 m, entrance pupil diameter of system 2.363114 m, pixelscale of 0.001340057497357116 arcsec/pix.
# DEBUG:poppy:Initialized: Primary, fl =2.84e+00 m
# DEBUG:poppy:Initialized: Secondary, fl =-6.54e-01 m
# DEBUG:poppy:Initialized: M3, fl =4.30e-01 m
# DEBUG:poppy:Initialized: M4, fl =1.16e-01 m
# DEBUG:poppy:Initialized: M5, fl =1.99e-01 m
# DEBUG:poppy:Initialized: OAP1, fl =5.03e-01 m
# DEBUG:poppy:Initialized: OAP2, fl =5.79e-01 m
# DEBUG:poppy:Initialized: OAP3, fl =1.22e+00 m
# DEBUG:poppy:Initialized: OAP4, fl =4.47e-01 m
# DEBUG:poppy:Initialized: OAP5, fl =5.48e-01 m
# DEBUG:poppy:Initialized: OAP6, fl =5.48e-01 m
# DEBUG:poppy:Initialized: OAP7, fl =7.08e-01 m
# DEBUG:poppy:Initialized: OAP8, fl =2.10e-01 m
# DEBUG:poppy:Initialized: LENS 1, fl =1.05e-01 m
# DEBUG:poppy:Initialized: LENS 2, fl =-1.71e-01 m
# INFO:poppy:Initialized OpticalSystem: HLC Part 1
# INFO:poppy:Added optic: Roman Pupil after separation: 0.00e+00 m
# INFO:poppy:Added optic: Primary after separation: 0.00e+00 m
# INFO:poppy:Added optic: Secondary after separation: 2.29e+00 m
# INFO:poppy:Added optic: POMA_Fold after separation: 2.99e+00 m
# INFO:poppy:Added optic: M3 after separation: 1.68e+00 m
# INFO:poppy:Added optic: M4 after separation: 9.44e-01 m
# INFO:poppy:Added optic: M5 after separation: 4.29e-01 m
# INFO:poppy:Added optic: TT_Fold after separation: 3.51e-01 m
# INFO:poppy:Added optic: FSM after separation: 3.99e-01 m
# INFO:poppy:Added optic: OAP1 after separation: 3.55e-01 m
# INFO:poppy:Added optic: FOCM after separation: 7.68e-01 m
# INFO:poppy:Added optic: OAP2 after separation: 3.15e-01 m
# INFO:poppy:Added optic: DM1 Plane (No Optic) after separation: 7.76e-01 m
# INFO:poppy:Added optic: DM2 Plane (No Optic) after separation: 1.00e+00 m
# INFO:poppy:Added optic: OAP3 after separation: 3.95e-01 m
# INFO:poppy:Added optic: Fold3 after separation: 5.05e-01 m
# INFO:poppy:Added optic: OAP4 after separation: 1.16e+00 m
# INFO:poppy:Added optic: SPM Plane (No Optic) after separation: 4.23e-01 m
# INFO:poppy:Added optic: OAP5 after separation: 4.09e-01 m
# INFO:poppy:Added optic: FPM Plane (No Optic) after separation: 5.48e-01 m
# INFO:poppy:Initialized OpticalSystem: HLC part 2
# INFO:poppy:Added optic: FPM Plane (No Optic) after separation: 0.00e+00 m
# INFO:poppy:Added optic: OAP6 after separation: 5.48e-01 m
# INFO:poppy:Added optic: Lyot Stop after separation: 6.87e-01 m
# INFO:poppy:Added optic: OAP7 after separation: 4.02e-01 m
# INFO:poppy:Added optic: HLC Field Stop after separation: 7.08e-01 m
# INFO:poppy:Added optic: OAP8 after separation: 2.10e-01 m
# INFO:poppy:Added optic: Filter after separation: 3.68e-01 m
# INFO:poppy:Added optic: LENS 1 after separation: 2.14e-01 m
# INFO:poppy:Added optic: LENS 2 after separation: 3.04e-03 m
# INFO:poppy:Added optic: Fold4 after separation: 2.02e-01 m
# INFO:poppy:Added detector with pixelscale=2.9587988e-06 m / pix and oversampling=1: Detector
# INFO:poppy:Added detector: Detector after separation: 5.00e-02 m
# DEBUG:poppy:Padded WF array for oversampling by 3.303, to (1024, 1024).
# Not employing polarization aberrations.
# INFO:poppy:Calculating PSF with 1 wavelengths
# INFO:poppy:User requested saving intermediate wavefronts in call to poppy.calc_psf
# INFO:poppy: Propagating wavelength = 5.75e-07 m
# INFO:poppy:Using user-defined FresnelWavefront() for the input wavefront of the FresnelOpticalSystem().
# DEBUG:poppy:Input wavefront has wavelength=0.575 microns, npix=310, diam=2.370761618122977 m, pixel scale=0.0076476181229773454 m / pix
# DEBUG:poppy:  Propagating wavefront to Pupil plane: Roman Pupil  after distance 0.0 m
# DEBUG:poppy:Array shape (312, 312) is smaller than desired shape [1024, 1024]; will attempt to zero-pad the array
# DEBUG:poppy:  Padded with a 356 x 356 border to  match the desired shape
# DEBUG:poppy:  Multiplied WF by phasor for Pupil plane: Roman Pupil
# DEBUG:poppy:normalizing at first plane (entrance pupil) to 1.0 total intensity
# DEBUG:poppy:  Propagating wavefront to Lens: Primary, with focal length 2.83827920690472 m after distance 0.0 m
# DEBUG:poppy:------ Applying Lens: Primary ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:1.185e+00 m, z_w0=0.000e+00 m
# z=0.000e+00 m, z_r=7.677e+06 m
# DEBUG:poppy:  Beam radius at Primary =1.19e+00 m
# DEBUG:poppy: input flat wavefront and Primary has output beam curvature of =-2.84e+00 m
# DEBUG:poppy:Primary has a curvature of =-2.84e+00 m
# DEBUG:poppy:Primary has a curved output wavefront, with waist at 2.838279206904332 m
# DEBUG:poppy:Post Optic Parameters:w_0:4.382e-07 m, z_w0=2.838e+00 m
# z=0.000e+00 m, z_r=1.049e-06 m
# DEBUG:poppy:Set output beam focal length to 2.83827920690472 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =2.08e+13 m
# DEBUG:poppy:Applying spherical lens phase =4.82e-14 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Primary
# DEBUG:poppy:------ Optic: Primary applied ------
# DEBUG:poppy:  Propagating wavefront to Lens: Secondary, with focal length -0.654200796568004 m after distance 2.285150508110035 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 2.838279206904332 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 0.0076476181229773454 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=2.838279206904332 m
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.018180 s, full function  in 0.020 s
# DEBUG:poppy:Applying spherical phase curvature =2.84e+00 m
# DEBUG:poppy:Applying spherical lens phase =3.52e-01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 2.0839956588015625e-07 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=-0.5531286987942967 m
# DEBUG:poppy:Applying spherical phase curvature =-5.53e-01 m
# DEBUG:poppy:Applying spherical lens phase =-1.81e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.017844 s, full function  in 0.020 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 2.29e+00 m ------
# DEBUG:poppy:------ Applying Lens: Secondary ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:4.382e-07 m, z_w0=2.838e+00 m
# z=2.285e+00 m, z_r=1.049e-06 m
# DEBUG:poppy:  Beam radius at Secondary =2.31e-01 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:4.382e-07 m, z_w0=2.838e+00 m
# z=2.285e+00 m, z_r=1.049e-06 m
# DEBUG:poppy: input curved wavefront and Secondary has output beam curvature of =-3.58e+00 m
# DEBUG:poppy:Secondary has a curvature of =-3.58e+00 m
# DEBUG:poppy:Secondary has a curved output wavefront, with waist at 5.865339732240842 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.837e-06 m, z_w0=5.865e+00 m
# z=2.285e+00 m, z_r=4.396e-05 m
# DEBUG:poppy:Magnification: 6.472615202347421  from R_in = -0.5531286987942967 m, R_out = -3.5801892246706126 m
# DEBUG:poppy:Output beam focal length is now 18.37108914311807 m
# DEBUG:poppy:Spherical to Spherical wavefront propagation.
# DEBUG:poppy:1/fl=-1.5286e+00 1 / m
# DEBUG:poppy:1.0/(R_input_beam)=-1.8079e+00 1 / m
# DEBUG:poppy:1.0/(self.z-self.z_w0)=-2.7931e-01 1 / m
# DEBUG:poppy:Applying spherical phase curvature =2.81e+10 m
# DEBUG:poppy:Applying spherical lens phase =3.56e-11 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Secondary
# DEBUG:poppy:------ Optic: Secondary applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: POMA_Fold after distance 2.993753469304728 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 5.865339732240842 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 0.0014903808797062871 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=3.5801892241308066 m
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.019162 s, full function  in 0.022 s
# DEBUG:poppy:Applying spherical phase curvature =3.58e+00 m
# DEBUG:poppy:Applying spherical lens phase =2.79e-01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 1.348890198075122e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=-0.5864357548260788 m
# DEBUG:poppy:Applying spherical phase curvature =-5.86e-01 m
# DEBUG:poppy:Applying spherical lens phase =-1.71e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.017853 s, full function  in 0.020 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 5.28e+00 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: POMA_Fold
# DEBUG:poppy:  Propagating wavefront to Lens: M3, with focal length 0.430216463069001 m after distance 1.680935841598811 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 5.865339732240842 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 0.00024412470443684539 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.5864357548260788 m
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.018717 s, full function  in 0.022 s
# DEBUG:poppy:Applying spherical phase curvature =5.86e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.71e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 1.348890198075122e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=1.0945000867727321 m
# DEBUG:poppy:Applying spherical phase curvature =1.09e+00 m
# DEBUG:poppy:Applying spherical lens phase =9.14e-01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.018391 s, full function  in 0.021 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 6.96e+00 m ------
# DEBUG:poppy:------ Applying Lens: M3 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:2.837e-06 m, z_w0=5.865e+00 m
# z=6.960e+00 m, z_r=4.396e-05 m
# DEBUG:poppy:  Beam radius at M3 =7.06e-02 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:2.837e-06 m, z_w0=5.865e+00 m
# z=6.960e+00 m, z_r=4.396e-05 m
# DEBUG:poppy: input curved wavefront and M3 has output beam curvature of =-7.09e-01 m
# DEBUG:poppy:M3 has a curvature of =-7.09e-01 m
# DEBUG:poppy:M3 has a curved output wavefront, with waist at 7.668681552494993 m
# DEBUG:poppy:Post Optic Parameters:w_0:1.837e-06 m, z_w0=7.669e+00 m
# z=6.960e+00 m, z_r=1.844e-05 m
# DEBUG:poppy:Magnification: -0.6476397238589359  from R_in = 1.0945000867727321 m, R_out = -0.7088417339610736 m
# DEBUG:poppy:Output beam focal length is now -11.897847099636882 m
# DEBUG:poppy:Spherical to Spherical wavefront propagation.
# DEBUG:poppy:1/fl=2.3244e+00 1 / m
# DEBUG:poppy:1.0/(R_input_beam)=9.1366e-01 1 / m
# DEBUG:poppy:1.0/(self.z-self.z_w0)=-1.4108e+00 1 / m
# DEBUG:poppy:Applying spherical phase curvature =4.12e+08 m
# DEBUG:poppy:Applying spherical lens phase =2.43e-09 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: M3
# DEBUG:poppy:------ Optic: M3 applied ------
# DEBUG:poppy:  Propagating wavefront to Lens: M4, with focal length 0.11623911483359 m after distance 0.943514749358944 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 7.668681552494993 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 0.0004556245215108646 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.7088417334814192 m
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.017026 s, full function  in 0.019 s
# DEBUG:poppy:Applying spherical phase curvature =7.09e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.41e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 8.735948748062588e-07 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=0.23467301587752498 m
# DEBUG:poppy:Applying spherical phase curvature =2.35e-01 m
# DEBUG:poppy:Applying spherical lens phase =4.26e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013979 s, full function  in 0.016 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 7.90e+00 m ------
# DEBUG:poppy:------ Applying Lens: M4 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:1.837e-06 m, z_w0=7.669e+00 m
# z=7.903e+00 m, z_r=1.844e-05 m
# DEBUG:poppy:  Beam radius at M4 =2.34e-02 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:1.837e-06 m, z_w0=7.669e+00 m
# z=7.903e+00 m, z_r=1.844e-05 m
# DEBUG:poppy: input curved wavefront and M4 has output beam curvature of =-2.30e-01 m
# DEBUG:poppy:M4 has a curvature of =-2.30e-01 m
# DEBUG:poppy:M4 has a curved output wavefront, with waist at 8.133678682270437 m
# DEBUG:poppy:Post Optic Parameters:w_0:1.803e-06 m, z_w0=8.134e+00 m
# z=7.903e+00 m, z_r=1.776e-05 m
# DEBUG:poppy:Magnification: -0.9814682544834251  from R_in = 0.23467301587752498 m, R_out = -0.23032411526767554 m
# DEBUG:poppy:Output beam focal length is now 11.677359224991292 m
# DEBUG:poppy:Spherical to Spherical wavefront propagation.
# DEBUG:poppy:1/fl=8.6030e+00 1 / m
# DEBUG:poppy:1.0/(R_input_beam)=4.2612e+00 1 / m
# DEBUG:poppy:1.0/(self.z-self.z_w0)=-4.3417e+00 1 / m
# DEBUG:poppy:Applying spherical phase curvature =1.92e+07 m
# DEBUG:poppy:Applying spherical lens phase =5.21e-08 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: M4
# DEBUG:poppy:------ Optic: M4 applied ------
# DEBUG:poppy:  Propagating wavefront to Lens: M5, with focal length 0.198821518772608 m after distance 0.429145636743193 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 8.133678682270437 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 0.00015084154264671494 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.23032411389791907 m
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.017200 s, full function  in 0.020 s
# DEBUG:poppy:Applying spherical phase curvature =2.30e-01 m
# DEBUG:poppy:Applying spherical lens phase =4.34e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 8.574056318027033e-07 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=0.19882152284527344 m
# DEBUG:poppy:Applying spherical phase curvature =1.99e-01 m
# DEBUG:poppy:Applying spherical lens phase =5.03e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.014759 s, full function  in 0.017 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 8.33e+00 m ------
# DEBUG:poppy:------ Applying Lens: M5 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:1.803e-06 m, z_w0=8.134e+00 m
# z=8.333e+00 m, z_r=1.776e-05 m
# DEBUG:poppy:  Beam radius at M5 =2.02e-02 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:1.803e-06 m, z_w0=8.134e+00 m
# z=8.333e+00 m, z_r=1.776e-05 m
# DEBUG:poppy: input curved wavefront and M5 has output beam curvature of =-6.98e+06 m
# DEBUG:poppy:M5 has a curvature of =-6.98e+06 m
# DEBUG:poppy:M5 has a curved output wavefront, with waist at 9.041618185825799 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.018e-02 m, z_w0=9.042e+00 m
# z=8.333e+00 m, z_r=2.226e+03 m
# DEBUG:poppy:Magnification: -35130855.62744164  from R_in = 0.19882152284527344 m, R_out = -6984770.21470539 m
# DEBUG:poppy:Output beam focal length is now -410235621.0429429 m
# DEBUG:poppy:Spherical to Planar.
# DEBUG:poppy:Applying spherical phase curvature =-9.71e+06 m
# DEBUG:poppy:Applying spherical lens phase =-1.03e-07 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: M5
# DEBUG:poppy:------ Optic: M5 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: TT_Fold after distance 0.35112543122077 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 9.041618185825799 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.35112543122077 m
# DEBUG:poppy:  Constant Pixelscale: 0.0001302101838570064 m / pix
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.014218 s, full function  in 0.017 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013997 s, full function  in 0.016 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 8.68e+00 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: TT_Fold
# DEBUG:poppy:  Propagating wavefront to Optic: FSM after distance 0.399012811707006 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 9.041618185825799 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.399012811707006 m
# DEBUG:poppy:  Constant Pixelscale: 0.0001302101838570064 m / pix
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.013829 s, full function  in 0.016 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.012683 s, full function  in 0.015 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 9.08e+00 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: FSM
# DEBUG:poppy:  Propagating wavefront to Lens: OAP1, with focal length 0.503331895563883 m after distance 0.354826767220001 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 9.041618185825799 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.354826767220001 m
# DEBUG:poppy:  Constant Pixelscale: 0.0001302101838570064 m / pix
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.016690 s, full function  in 0.019 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013308 s, full function  in 0.016 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 9.44e+00 m ------
# DEBUG:poppy:------ Applying Lens: OAP1 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:2.018e-02 m, z_w0=9.042e+00 m
# z=9.437e+00 m, z_r=2.226e+03 m
# DEBUG:poppy:  Beam radius at OAP1 =2.02e-02 m
# DEBUG:poppy: input flat wavefront and OAP1 has output beam curvature of =-5.03e-01 m
# DEBUG:poppy:OAP1 has a curvature of =-5.03e-01 m
# DEBUG:poppy:OAP1 has a curved output wavefront, with waist at 9.940797085082382 m
# DEBUG:poppy:Post Optic Parameters:w_0:4.565e-06 m, z_w0=9.941e+00 m
# z=9.437e+00 m, z_r=1.138e-04 m
# DEBUG:poppy:Magnification: -0.0  from R_in = inf m, R_out = -0.503331895563883 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =9.84e+06 m
# DEBUG:poppy:Applying spherical lens phase =1.02e-07 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP1
# DEBUG:poppy:------ Optic: OAP1 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: FOCM after distance 0.768029932093727 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 9.940797085082382 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 0.0001302101838570064 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.5033318698188936 m
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.016651 s, full function  in 0.019 s
# DEBUG:poppy:Applying spherical phase curvature =5.03e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.99e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 2.1705878401522554e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=0.2646980622748334 m
# DEBUG:poppy:Applying spherical phase curvature =2.65e-01 m
# DEBUG:poppy:Applying spherical lens phase =3.78e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.016376 s, full function  in 0.018 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.02e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: FOCM
# DEBUG:poppy:  Propagating wavefront to Lens: OAP2, with focal length 0.57920557125499 m after distance 0.314507535543064 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 9.940797085082382 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 6.847645742718599e-05 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=-0.2646980622748334 m
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.016930 s, full function  in 0.019 s
# DEBUG:poppy:Applying spherical phase curvature =-2.65e-01 m
# DEBUG:poppy:Applying spherical lens phase =-3.78e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 2.1705878401522554e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=0.5792055978178983 m
# DEBUG:poppy:Applying spherical phase curvature =5.79e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.73e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.015859 s, full function  in 0.018 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.05e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP2 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:4.565e-06 m, z_w0=9.941e+00 m
# z=1.052e+01 m, z_r=1.138e-04 m
# DEBUG:poppy:  Beam radius at OAP2 =2.32e-02 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:4.565e-06 m, z_w0=9.941e+00 m
# z=1.052e+01 m, z_r=1.138e-04 m
# DEBUG:poppy: input curved wavefront and OAP2 has output beam curvature of =-6.86e+06 m
# DEBUG:poppy:OAP2 has a curvature of =-6.86e+06 m
# DEBUG:poppy:OAP2 has a curved output wavefront, with waist at 11.78690014257149 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.322e-02 m, z_w0=1.179e+01 m
# z=1.052e+01 m, z_r=2.947e+03 m
# DEBUG:poppy:Magnification: -11836126.012682276  from R_in = 0.5792055978178983 m, R_out = -6855550.443023614 m
# DEBUG:poppy:Output beam focal length is now -0.0 m
# DEBUG:poppy:Spherical to Planar.
# DEBUG:poppy:Applying spherical phase curvature =-1.26e+07 m
# DEBUG:poppy:Applying spherical lens phase =-7.92e-08 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP2
# DEBUG:poppy:------ Optic: OAP2 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: DM1 Plane (No Optic) after distance 0.775857408587825 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 11.78690014257149 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.775857408587825 m
# DEBUG:poppy:  Constant Pixelscale: 0.00014983845034492364 m / pix
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.016627 s, full function  in 0.019 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013656 s, full function  in 0.016 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.13e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: DM1 Plane (No Optic)
# DEBUG:poppy:  Propagating wavefront to Optic: DM2 Plane (No Optic) after distance 1.0 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 11.78690014257149 m
# DEBUG:poppy:  Plane to Plane Regime, dz=1.0 m
# DEBUG:poppy:  Constant Pixelscale: 0.00014983845034492364 m / pix
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.016543 s, full function  in 0.019 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013366 s, full function  in 0.016 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.23e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: DM2 Plane (No Optic)
# DEBUG:poppy:  Propagating wavefront to Lens: OAP3, with focal length 1.217276467668519 m after distance 0.394833855161549 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 11.78690014257149 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.394833855161549 m
# DEBUG:poppy:  Constant Pixelscale: 0.00014983845034492364 m / pix
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.016538 s, full function  in 0.019 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013406 s, full function  in 0.016 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.27e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP3 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:2.322e-02 m, z_w0=1.179e+01 m
# z=1.269e+01 m, z_r=2.947e+03 m
# DEBUG:poppy:  Beam radius at OAP3 =2.32e-02 m
# DEBUG:poppy: input flat wavefront and OAP3 has output beam curvature of =-1.22e+00 m
# DEBUG:poppy:OAP3 has a curvature of =-1.22e+00 m
# DEBUG:poppy:OAP3 has a curved output wavefront, with waist at 13.90797020664337 m
# DEBUG:poppy:Post Optic Parameters:w_0:9.593e-06 m, z_w0=1.391e+01 m
# z=1.269e+01 m, z_r=5.028e-04 m
# DEBUG:poppy:Magnification: -0.0  from R_in = inf m, R_out = -1.217276467668519 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =7.14e+06 m
# DEBUG:poppy:Applying spherical lens phase =1.40e-07 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP3
# DEBUG:poppy:------ Optic: OAP3 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: Fold3 after distance 0.505329955078121 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 13.90797020664337 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 0.00014983845034492364 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=1.2172762599937155 m
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.017239 s, full function  in 0.020 s
# DEBUG:poppy:Applying spherical phase curvature =1.22e+00 m
# DEBUG:poppy:Applying spherical lens phase =8.22e-01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 4.561774019454627e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=-0.7119463049155943 m
# DEBUG:poppy:Applying spherical phase curvature =-7.12e-01 m
# DEBUG:poppy:Applying spherical lens phase =-1.40e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.015915 s, full function  in 0.018 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.32e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Fold3
# DEBUG:poppy:  Propagating wavefront to Lens: OAP4, with focal length 0.446951159052363 m after distance 1.158897671642761 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 13.90797020664337 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 8.763576072525877e-05 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.7119463049155943 m
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.016595 s, full function  in 0.019 s
# DEBUG:poppy:Applying spherical phase curvature =7.12e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.40e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 4.561774019454627e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=0.4469513667271663 m
# DEBUG:poppy:Applying spherical phase curvature =4.47e-01 m
# DEBUG:poppy:Applying spherical lens phase =2.24e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.014746 s, full function  in 0.017 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.44e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP4 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:9.593e-06 m, z_w0=1.391e+01 m
# z=1.435e+01 m, z_r=5.028e-04 m
# DEBUG:poppy:  Beam radius at OAP4 =8.53e-03 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:9.593e-06 m, z_w0=1.391e+01 m
# z=1.435e+01 m, z_r=5.028e-04 m
# DEBUG:poppy: input curved wavefront and OAP4 has output beam curvature of =-2.58e+05 m
# DEBUG:poppy:OAP4 has a curvature of =-2.58e+05 m
# DEBUG:poppy:OAP4 has a curved output wavefront, with waist at 14.965981169645897 m
# DEBUG:poppy:Post Optic Parameters:w_0:8.528e-03 m, z_w0=1.497e+01 m
# z=1.435e+01 m, z_r=3.973e+02 m
# DEBUG:poppy:Magnification: -577995.3604155597  from R_in = 0.4469513667271663 m, R_out = -258335.81629969546 m
# DEBUG:poppy:Output beam focal length is now -0.0 m
# DEBUG:poppy:Spherical to Planar.
# DEBUG:poppy:Applying spherical phase curvature =-9.62e+05 m
# DEBUG:poppy:Applying spherical lens phase =-1.04e-06 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP4
# DEBUG:poppy:------ Optic: OAP4 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: SPM Plane (No Optic) after distance 0.423013568764728 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 14.965981169645897 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.423013568764728 m
# DEBUG:poppy:  Constant Pixelscale: 5.5016681398428e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.016230 s, full function  in 0.018 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.012572 s, full function  in 0.015 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.48e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: SPM Plane (No Optic)
# DEBUG:poppy:  Propagating wavefront to Lens: OAP5, with focal length 0.548189354706822 m after distance 0.408810704327559 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 14.965981169645897 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.408810704327559 m
# DEBUG:poppy:  Constant Pixelscale: 5.5016681398428e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.016393 s, full function  in 0.019 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013924 s, full function  in 0.016 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.52e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP5 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:8.528e-03 m, z_w0=1.497e+01 m
# z=1.519e+01 m, z_r=3.973e+02 m
# DEBUG:poppy:  Beam radius at OAP5 =8.53e-03 m
# DEBUG:poppy: input flat wavefront and OAP5 has output beam curvature of =-5.48e-01 m
# DEBUG:poppy:OAP5 has a curvature of =-5.48e-01 m
# DEBUG:poppy:OAP5 has a curved output wavefront, with waist at 15.734934157594962 m
# DEBUG:poppy:Post Optic Parameters:w_0:1.177e-05 m, z_w0=1.573e+01 m
# z=1.519e+01 m, z_r=7.564e-04 m
# DEBUG:poppy:Magnification: -0.0  from R_in = inf m, R_out = -0.548189354706822 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =2.88e+05 m
# DEBUG:poppy:Applying spherical lens phase =3.47e-06 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP5
# DEBUG:poppy:------ Optic: OAP5 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: FPM Plane (No Optic) after distance 0.548189354706822 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 15.734934157594962 m
# DEBUG:poppy:  Spherical to Plane Regime, outside Z_R to inside Z_R
# DEBUG:poppy:Spherical to Waist propagation, dz=0.5481883111321384 m
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.017872 s, full function  in 0.020 s
# DEBUG:poppy:Applying spherical phase curvature =5.48e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.82e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.016875 s, full function  in 0.019 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.016538 s, full function  in 0.019 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.57e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: FPM Plane (No Optic)
# INFO:poppy:  Calculation completed in 4.566 s
# INFO:poppy:PSF Calculation completed.
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.014639 s, full function  in 0.020 s
# DEBUG:poppy:MatrixFourierTransform initialized using centering type = ADJUSTABLE
# DEBUG:poppy:Forward MatrixFourierTransform: array shape (1024, 1024), centering style ADJUSTABLE, output region size 23.54857611718359 in lambda / D units, output array size 267 pixels, offset None
# DEBUG:poppy:MatrixFourierTransform initialized using centering type = ADJUSTABLE
# DEBUG:poppy:Inverse MatrixFourierTransform: array shape (267, 267), centering style ADJUSTABLE, output region size 23.54857611718359 in lambda / D units, output array size 1024 pixels, offset None
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.013848 s, full function  in 0.018 s
# INFO:poppy:Calculating PSF with 1 wavelengths
# INFO:poppy:User requested saving intermediate wavefronts in call to poppy.calc_psf
# INFO:poppy: Propagating wavelength = 5.75e-07 m
# INFO:poppy:Using user-defined FresnelWavefront() for the input wavefront of the FresnelOpticalSystem().
# DEBUG:poppy:Input wavefront has wavelength=0.575 microns, npix=310, diam=1.0 m, pixel scale=0.0032258064516129032 m / pix
# DEBUG:poppy:  Propagating wavefront to Optic: FPM Plane (No Optic) after distance 0.0 m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: FPM Plane (No Optic)
# DEBUG:poppy:  Propagating wavefront to Lens: OAP6, with focal length 0.5481285905651814 m after distance 0.5481285905651814 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 15.734934157594962 m
# DEBUG:poppy:  Plane to Spherical Regime, inside Z_R to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 5.595040941037807e-06 m / pix
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.014071 s, full function  in 0.016 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.014421 s, full function  in 0.016 s
# DEBUG:poppy:Waist to Spherical propagation, dz=0.5481296341398636 m
# DEBUG:poppy:Applying spherical phase curvature =5.48e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.82e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013894 s, full function  in 0.016 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.63e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP6 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:1.177e-05 m, z_w0=1.573e+01 m
# z=1.628e+01 m, z_r=7.564e-04 m
# DEBUG:poppy:  Beam radius at OAP6 =8.53e-03 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:1.177e-05 m, z_w0=1.573e+01 m
# z=1.628e+01 m, z_r=7.564e-04 m
# DEBUG:poppy: input curved wavefront and OAP6 has output beam curvature of =-1.44e+05 m
# DEBUG:poppy:OAP6 has a curvature of =-1.44e+05 m
# DEBUG:poppy:OAP6 has a curved output wavefront, with waist at 17.37926021493852 m
# DEBUG:poppy:Post Optic Parameters:w_0:8.527e-03 m, z_w0=1.738e+01 m
# z=1.628e+01 m, z_r=3.972e+02 m
# DEBUG:poppy:Magnification: -262607.12643737416  from R_in = 0.5481296341398636 m, R_out = -143942.7481366388 m
# DEBUG:poppy:Output beam focal length is now -0.0 m
# DEBUG:poppy:Spherical to Planar.
# DEBUG:poppy:Applying spherical phase curvature =-2.88e+05 m
# DEBUG:poppy:Applying spherical lens phase =-3.47e-06 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP6
# DEBUG:poppy:------ Optic: OAP6 applied ------
# DEBUG:poppy:  Propagating wavefront to Pupil plane: Lyot Stop  after distance 0.687476361491529 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 17.37926021493852 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.687476361491529 m
# DEBUG:poppy:  Constant Pixelscale: 5.501079252169743e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.014194 s, full function  in 0.017 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.012799 s, full function  in 0.015 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.70e+01 m ------
# DEBUG:poppy:Array shape (312, 312) is smaller than desired shape [1024, 1024]; will attempt to zero-pad the array
# DEBUG:poppy:  Padded with a 356 x 356 border to  match the desired shape
# DEBUG:poppy:  Multiplied WF by phasor for Pupil plane: Lyot Stop
# DEBUG:poppy:  Propagating wavefront to Lens: OAP7, with focal length 0.70825142092381 m after distance 0.401748561745987 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 17.37926021493852 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.401748561745987 m
# DEBUG:poppy:  Constant Pixelscale: 5.501079252169743e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.013065 s, full function  in 0.015 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013734 s, full function  in 0.016 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.74e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP7 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:8.527e-03 m, z_w0=1.738e+01 m
# z=1.737e+01 m, z_r=3.972e+02 m
# DEBUG:poppy:  Beam radius at OAP7 =8.53e-03 m
# DEBUG:poppy: input flat wavefront and OAP7 has output beam curvature of =-7.08e-01 m
# DEBUG:poppy:OAP7 has a curvature of =-7.08e-01 m
# DEBUG:poppy:OAP7 has a curved output wavefront, with waist at 18.0805378843227 m
# DEBUG:poppy:Post Optic Parameters:w_0:1.520e-05 m, z_w0=1.808e+01 m
# z=1.737e+01 m, z_r=1.263e-03 m
# DEBUG:poppy:Magnification: -0.0  from R_in = inf m, R_out = -0.70825142092381 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =2.23e+05 m
# DEBUG:poppy:Applying spherical lens phase =4.49e-06 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP7
# DEBUG:poppy:------ Optic: OAP7 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: HLC Field Stop after distance 0.70825142092381 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 18.0805378843227 m
# DEBUG:poppy:  Spherical to Plane Regime, outside Z_R to inside Z_R
# DEBUG:poppy:Spherical to Waist propagation, dz=0.7082491693503563 m
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013494 s, full function  in 0.015 s
# DEBUG:poppy:Applying spherical phase curvature =7.08e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.41e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.013919 s, full function  in 0.016 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013725 s, full function  in 0.016 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.81e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: HLC Field Stop
# DEBUG:poppy:  Propagating wavefront to Lens: OAP8, with focal length 0.2104895661807894 m after distance 0.2104895661807894 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 18.0805378843227 m
# DEBUG:poppy:  Plane to Spherical Regime, inside Z_R to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 7.229463346183769e-06 m / pix
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.013584 s, full function  in 0.016 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013600 s, full function  in 0.016 s
# DEBUG:poppy:Waist to Spherical propagation, dz=0.2104918177542423 m
# DEBUG:poppy:Applying spherical phase curvature =2.10e-01 m
# DEBUG:poppy:Applying spherical lens phase =4.75e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013897 s, full function  in 0.016 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.83e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP8 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:1.520e-05 m, z_w0=1.808e+01 m
# z=1.829e+01 m, z_r=1.263e-03 m
# DEBUG:poppy:  Beam radius at OAP8 =2.53e-03 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:1.520e-05 m, z_w0=1.808e+01 m
# z=1.829e+01 m, z_r=1.263e-03 m
# DEBUG:poppy: input curved wavefront and OAP8 has output beam curvature of =-4.51e+03 m
# DEBUG:poppy:OAP8 has a curvature of =-4.51e+03 m
# DEBUG:poppy:OAP8 has a curved output wavefront, with waist at 18.564075948239374 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.534e-03 m, z_w0=1.856e+01 m
# z=1.829e+01 m, z_r=3.509e+01 m
# DEBUG:poppy:Magnification: -21419.14896570923  from R_in = 0.2104918177542423 m, R_out = -4508.555600541035 m
# DEBUG:poppy:Output beam focal length is now -0.0 m
# DEBUG:poppy:Spherical to Planar.
# DEBUG:poppy:Applying spherical phase curvature =-1.97e+04 m
# DEBUG:poppy:Applying spherical lens phase =-5.08e-05 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP8
# DEBUG:poppy:------ Optic: OAP8 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: Filter after distance 0.36756158767400804 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 18.564075948239374 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.36756158767400804 m
# DEBUG:poppy:  Constant Pixelscale: 1.6349220323992387e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.014417 s, full function  in 0.017 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013435 s, full function  in 0.015 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.87e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Filter
# DEBUG:poppy:  Propagating wavefront to Lens: LENS 1, with focal length 0.10490069216127479 m after distance 0.21432764805243154 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 18.564075948239374 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.21432764805243154 m
# DEBUG:poppy:  Constant Pixelscale: 1.6349220323992387e-05 m / pix
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.014265 s, full function  in 0.017 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.012904 s, full function  in 0.015 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.89e+01 m ------
# DEBUG:poppy:------ Applying Lens: LENS 1 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:2.534e-03 m, z_w0=1.856e+01 m
# z=1.887e+01 m, z_r=3.509e+01 m
# DEBUG:poppy:  Beam radius at LENS 1 =2.53e-03 m
# DEBUG:poppy: input flat wavefront and LENS 1 has output beam curvature of =-1.05e-01 m
# DEBUG:poppy:LENS 1 has a curvature of =-1.05e-01 m
# DEBUG:poppy:LENS 1 has a curved output wavefront, with waist at 18.977818692366938 m
# DEBUG:poppy:Post Optic Parameters:w_0:7.576e-06 m, z_w0=1.898e+01 m
# z=1.887e+01 m, z_r=3.136e-04 m
# DEBUG:poppy:Magnification: -0.0  from R_in = inf m, R_out = -0.10490069216127479 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =1.17e+04 m
# DEBUG:poppy:Applying spherical lens phase =8.52e-05 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: LENS 1
# DEBUG:poppy:------ Optic: LENS 1 applied ------
# DEBUG:poppy:  Propagating wavefront to Lens: LENS 2, with focal length -0.17078291119000114 m after distance 0.0030356875488610326 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 18.977818692366938 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 1.6349220323992387e-05 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.10489975456355793 m
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013364 s, full function  in 0.015 s
# DEBUG:poppy:Applying spherical phase curvature =1.05e-01 m
# DEBUG:poppy:Applying spherical lens phase =9.53e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 3.6028428027845805e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=-0.10186406701469863 m
# DEBUG:poppy:Applying spherical phase curvature =-1.02e-01 m
# DEBUG:poppy:Applying spherical lens phase =-9.82e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.015750 s, full function  in 0.018 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.89e+01 m ------
# DEBUG:poppy:------ Applying Lens: LENS 2 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:7.576e-06 m, z_w0=1.898e+01 m
# z=1.888e+01 m, z_r=3.136e-04 m
# DEBUG:poppy:  Beam radius at LENS 2 =2.46e-03 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:7.576e-06 m, z_w0=1.898e+01 m
# z=1.888e+01 m, z_r=3.136e-04 m
# DEBUG:poppy: input curved wavefront and LENS 2 has output beam curvature of =-2.52e-01 m
# DEBUG:poppy:LENS 2 has a curvature of =-2.52e-01 m
# DEBUG:poppy:LENS 2 has a curved output wavefront, with waist at 19.128367999039625 m
# DEBUG:poppy:Post Optic Parameters:w_0:1.877e-05 m, z_w0=1.913e+01 m
# z=1.888e+01 m, z_r=1.926e-03 m
# DEBUG:poppy:Magnification: 2.4780874480050934  from R_in = -0.10186406701469863 m, R_out = -0.25242806587187433 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Spherical to Spherical wavefront propagation.
# DEBUG:poppy:1/fl=-5.8554e+00 1 / m
# DEBUG:poppy:1.0/(R_input_beam)=-9.8170e+00 1 / m
# DEBUG:poppy:1.0/(self.z-self.z_w0)=-3.9618e+00 1 / m
# DEBUG:poppy:Applying spherical phase curvature =7.27e+03 m
# DEBUG:poppy:Applying spherical lens phase =1.38e-04 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: LENS 2
# DEBUG:poppy:------ Optic: LENS 2 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: Fold4 after distance 0.20243215566774464 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 19.128367999039625 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 1.587609124206465e-05 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.2524133736873857 m
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013638 s, full function  in 0.015 s
# DEBUG:poppy:Applying spherical phase curvature =2.52e-01 m
# DEBUG:poppy:Applying spherical lens phase =3.96e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 8.927639877023056e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=-0.04998121801964217 m
# DEBUG:poppy:Applying spherical phase curvature =-5.00e-02 m
# DEBUG:poppy:Applying spherical lens phase =-2.00e+01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.013783 s, full function  in 0.016 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.91e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Fold4
# DEBUG:poppy:  Propagating wavefront to Detector plane: Detector (256x256 pixels, 0.000 m / pix) after distance 0.050000152941020164 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 19.128367999039625 m
# DEBUG:poppy:  Spherical to Plane Regime, outside Z_R to inside Z_R
# DEBUG:poppy:Spherical to Waist propagation, dz=0.04998121801964217 m
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013575 s, full function  in 0.015 s
# DEBUG:poppy:Applying spherical phase curvature =5.00e-02 m
# DEBUG:poppy:Applying spherical lens phase =2.00e+01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.014115 s, full function  in 0.016 s
# DEBUG:poppy:using mkl_fft FFT of (1024, 1024) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.013360 s, full function  in 0.015 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.91e+01 m ------
# INFO:poppy:Resampling wavefront to detector with (256, 256) pixels and 2.9587988e-06 m / pix. Zoom factor is 3.01732
# DEBUG:poppy:Wavefront pixel scale:        0.000 m / pix
# DEBUG:poppy:Desired detector pixel scale: 0.000 m / pix
# DEBUG:poppy:Wavefront FOV:        (1024, 1024) pixels, 0.009 m
# DEBUG:poppy:Desired detector FOV: (256, 256) pixels, 0.001 m
# DEBUG:poppy:Array shape (1024, 1024) is smaller than desired shape [1026, 1026]; will attempt to zero-pad the array
# DEBUG:poppy:  Padded with a 1 x 1 border to  match the desired shape
# INFO:poppy:  Calculation completed in 2.691 s
# INFO:poppy:PSF Calculation completed.
# PSF calculated in 8.13s

# %%
import proper
import roman_phasec_proper
from IPython.display import clear_output

cor_type='hlc'
lambda_m=575e-9
final_sampling_lam0=0.1
output_dim=256
source_x_offset=0
source_y_offset=0
use_fpm=1
use_errors=0
use_lens_errors=0
use_hlc_dm_patterns=0
use_dm1=0
use_dm2=0
dm1_fname='hlc_best_contrast_dm1.fits'
dm2_fname='hlc_best_contrast_dm2.fits'
polaxis=0
use_field_stop=1
use_pupil_defocus=1

if use_dm1==0: dm1_m = 0
else: dm1_m = proper.prop_fits_read( roman_phasec_proper.lib_dir + '/examples/' + dm1_fname )
if use_dm2==0: dm2_m = 0
else: dm2_m = proper.prop_fits_read( roman_phasec_proper.lib_dir + '/examples/' + dm2_fname )

lam_array = np.array([lambda_m*1e6])
(wfs_2, wfs_sampling_m) = proper.prop_run_multi('roman_phasec', lam_array, output_dim, QUIET=False, 
                                                PASSVALUE={'cor_type':cor_type,
                                                           'final_sampling_lam0':final_sampling_lam0, 
                                                           'source_x_offset':source_x_offset,
                                                           'use_fpm':use_fpm,
                                                           'use_hlc_dm_patterns':use_hlc_dm_patterns,
                                                           'use_errors': use_errors,
                                                           'use_lens_errors':use_lens_errors,
                                                           'use_pupil_defocus':use_pupil_defocus,
                                                           'use_dm1':use_dm1, 'dm1_m':dm1_m, 
                                                           'use_dm2':use_dm2, 'dm2_m':dm2_m,
                                                           'use_field_stop':use_field_stop,
                                                           'polaxis':polaxis,
                                                          })
clear_output()

proper_psf = wfs_2[0]
psf_sampling_m = wfs_sampling_m[0]*u.m/u.pix

misc.myimshow2(np.abs(proper_psf)**2, np.angle(proper_psf), lognorm1=True,
               pxscl1=psf_sampling_m, pxscl2=psf_sampling_m,)

# %%
psf_sampling_m
# Out:
# <Quantity 2.95879877e-06 m / pix>

# %%
from scipy.ndimage import rotate
from matplotlib.patches import Circle

pop_int = rotate(wfs[-1].intensity, 180)
pop_phs = rotate(wfs[-1].phase, 180)
prop_int = np.abs(proper_psf)**2
prop_phs = np.angle(proper_psf)

pop_int = misc.mask_psf(pop_int, pixelscale=psf_sampling_m.value, pixelscale_lamD=0.1, iwa=None, owa=9.7)
prop_int = misc.mask_psf(prop_int, pixelscale=psf_sampling_m.value, pixelscale_lamD=0.1, iwa=None, owa=9.7)

psfs = np.ma.concatenate([pop_int, prop_int])
vmin = np.ma.min(psfs)
vmax = np.ma.max(psfs)
vmin = 1e-14

innwa = 2.8/final_sampling_lam0*psf_sampling_m.value * 1000 # inner and outer working angles in units of m
outwa = 9.7/final_sampling_lam0*psf_sampling_m.value * 1000

patches1 = [Circle((0,0),innwa,edgecolor='c', facecolor='none',lw=1),
            Circle((0,0),outwa,edgecolor='c', facecolor='none',lw=1)]
patches2 = [Circle((0,0),innwa,edgecolor='c', facecolor='none',lw=1),
            Circle((0,0),outwa,edgecolor='c', facecolor='none',lw=1)]
misc.myimshow2(pop_int, prop_int, 'POPPY PSF Intensity', 'PROPER PSF Intensity',
               cmap1='gist_heat', cmap2='gist_heat', 
               lognorm1=True, lognorm2=True, vmin1=vmin, vmax1=vmax, vmin2=vmin, vmax2=vmax,
               pxscl1=psf_pixelscale.to(u.mm/u.pix), pxscl2=psf_sampling_m.to(u.mm/u.pix),
               patches1=patches1, patches2=patches2)

patches1 = [Circle((0,0),innwa,edgecolor='c', facecolor='none',lw=1),
            Circle((0,0),outwa,edgecolor='c', facecolor='none',lw=1)]
patches2 = [Circle((0,0),innwa,edgecolor='c', facecolor='none',lw=1),
            Circle((0,0),outwa,edgecolor='c', facecolor='none',lw=1)]
misc.myimshow2(pop_phs, prop_phs, 'POPPY PSF Phase', 'PROPER PSF Phase',
               pxscl1=psf_pixelscale.to(u.mm/u.pix), pxscl2=psf_sampling_m.to(u.mm/u.pix),
               cmap1='viridis', cmap2='viridis', patches1=patches1, patches2=patches2)

# Difference
int_diff = np.abs(pop_int-prop_int)
phs_diff = pop_phs-prop_phs
# int_diff = pop_int/prop_int
# phs_diff = pop_phs/prop_phs
patches1 = [Circle((0,0),innwa,edgecolor='c', facecolor='none',lw=1),
            Circle((0,0),outwa,edgecolor='c', facecolor='none',lw=1)]
patches2 = [Circle((0,0),innwa,edgecolor='c', facecolor='none',lw=1),
            Circle((0,0),outwa,edgecolor='c', facecolor='none',lw=1)]
misc.myimshow2(int_diff, phs_diff, 'Intensity Diff', 'Phase Diff',
               pxscl=psf_sampling_m.to(u.mm/u.pix),
               lognorm1=True, 
               cmap1='gist_heat', cmap2='viridis',  
               patches1=patches1, patches2=patches2)
print(np.ma.mean(int_diff))
print(np.ma.sum(pop_int))
print(np.ma.sum(prop_int))
# Out:
# 7.644625289221626e-09
# 0.0009057138879000946
# 0.0009338117501275803

# %%
from astropy.io import fits

wf_dir = Path('/groups/douglase/kians-data-files/roman-cgi-wfs/hlc')
def save_waves(wfs, wf_dir, npix=1024):
    optics = ['polmap', 'primary', 'secondary', 'poma_fold', 'm3', 'm4', 'm5', 'tt_fold', 'fsm', 'oap1', 
              'focm', 'oap2', 'dm1', 'dm2', 'oap3', 'fold3', 'oap4', 'pupilmask', 'oap5', 'fpm', 'oap6',
              'lyotstop', 'oap7', 'fieldstop', 'oap8', 'filter', 
              'imaging_lens_lens1', 'imaging_lens_lens2', 'fold4', 'image']
    print('Saving wavefronts: ')
    for i,wf in enumerate(wfs):
        wavefront = misc.pad_or_crop(wf.wavefront, npix)

        wf_data = np.zeros(shape=(2,npix,npix))
        wf_data[0,:,:] = np.abs(wavefront)**2
        wf_data[1,:,:] = np.angle(wavefront)

        wf_fpath = wf_dir/(optics[i] + '_poppy.fits')
        hdr = fits.Header()
        hdr['PIXELSCL'] = wf.pixelscale.value

        wf_hdu = fits.PrimaryHDU(wf_data, header=hdr)
        wf_hdu.writeto(wf_fpath, overwrite=True)
        print(i, 'Saved '+optics[i]+' wavefront to ' + str(wf_fpath))
            
save_waves(wfs, wf_dir)
# Out:
# Saving wavefronts:
# 0 Saved polmap wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/polmap_poppy.fits
# 1 Saved primary wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/primary_poppy.fits
# 2 Saved secondary wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/secondary_poppy.fits
# 3 Saved poma_fold wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/poma_fold_poppy.fits
# 4 Saved m3 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/m3_poppy.fits
# 5 Saved m4 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/m4_poppy.fits
# 6 Saved m5 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/m5_poppy.fits
# 7 Saved tt_fold wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/tt_fold_poppy.fits
# 8 Saved fsm wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/fsm_poppy.fits
# 9 Saved oap1 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/oap1_poppy.fits
# 10 Saved focm wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/focm_poppy.fits
# 11 Saved oap2 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/oap2_poppy.fits
# 12 Saved dm1 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/dm1_poppy.fits
# 13 Saved dm2 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/dm2_poppy.fits
# 14 Saved oap3 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/oap3_poppy.fits
# 15 Saved fold3 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/fold3_poppy.fits
# 16 Saved oap4 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/oap4_poppy.fits
# 17 Saved pupilmask wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/pupilmask_poppy.fits
# 18 Saved oap5 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/oap5_poppy.fits
# 19 Saved fpm wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/fpm_poppy.fits
# 20 Saved oap6 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/oap6_poppy.fits
# 21 Saved lyotstop wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/lyotstop_poppy.fits
# 22 Saved oap7 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/oap7_poppy.fits
# 23 Saved fieldstop wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/fieldstop_poppy.fits
# 24 Saved oap8 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/oap8_poppy.fits
# 25 Saved filter wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/filter_poppy.fits
# 26 Saved imaging_lens_lens1 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/imaging_lens_lens1_poppy.fits
# 27 Saved imaging_lens_lens2 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/imaging_lens_lens2_poppy.fits
# 28 Saved fold4 wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/fold4_poppy.fits
# 29 Saved image wavefront to /groups/douglase/kians-data-files/roman-cgi-wfs/hlc/image_poppy.fits
