# %%
import numpy as np
import astropy.units as u
from pathlib import Path
from importlib import reload

import poppy_roman_cgi_phasec as cgi
from poppy_roman_cgi_phasec import spc
from poppy_roman_cgi_phasec import misc
reload(spc)

# set debugging mode for more information from POPPY as propagation is performed
import logging, sys
_log = logging.getLogger('poppy')
_log.setLevel("DEBUG")
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

mode = 'SPC825'
lambda_m = 546.25e-9*u.m
lambda_m = None

use_opds = False
use_apertures = False
polaxis = 0
cgi_dir = Path('C:/Users/Kian/Desktop/roman-cgi-phasec-data')

psf, wfs = spc.run(mode=mode,
                   npix=1000,
                   oversample=2048/1000,
                   npsf=512,
                   pixelscale_lamD=0.1,
#                    offsets=(4.5,0),
#                    dm1_fname='spc_wide_band4_best_contrast_dm1.fits', dm2_fname='spc_wide_band4_best_contrast_dm2.fits',
#                    use_fpm=False,
                   use_opds=use_opds,
#                    use_pupil_defocus=True,
                   polaxis=polaxis,
                   cgi_dir=cgi_dir,
                   display_mode=False,
                   display_inwave=True,
                   display_intermediates=False,
                   display_fpm=True,
                   display_psf=True)
# Out:
# DEBUG:poppy:Trans: C:\Users\Kian\Desktop\roman-cgi-phasec-data\spc-wide\pupil_SPC-20200610_1000.fits
# DEBUG:poppy:OPD: None
# INFO:poppy:Roman Pupil: Loaded amplitude transmission from C:\Users\Kian\Desktop\roman-cgi-phasec-data\spc-wide\pupil_SPC-20200610_1000.fits
# DEBUG:poppy:Trans: C:\Users\Kian\Desktop\roman-cgi-phasec-data\spc-wide\SPM_SPC-20200610_1000_rounded9_gray_rotated.fits
# DEBUG:poppy:OPD: None
# INFO:poppy:SPM: Loaded amplitude transmission from C:\Users\Kian\Desktop\roman-cgi-phasec-data\spc-wide\SPM_SPC-20200610_1000_rounded9_gray_rotated.fits
# DEBUG:poppy:Trans: C:\Users\Kian\Desktop\roman-cgi-phasec-data\spc-wide\FPM_SPC-20200610_0.1_lamc_div_D.fits
# DEBUG:poppy:OPD: None
# INFO:poppy:FPM: Loaded amplitude transmission from C:\Users\Kian\Desktop\roman-cgi-phasec-data\spc-wide\FPM_SPC-20200610_0.1_lamc_div_D.fits
# DEBUG:poppy:FixedSamplingImagePlaneElement FPM initialized:centering style ADJUSTABLE, central wavelength for operation 8.25e-07 m, entrance pupil diameter of system 2.363114 m, pixelscale of 0.007201026491056061 arcsec/pix.
# DEBUG:poppy:Trans: C:\Users\Kian\Desktop\roman-cgi-phasec-data\spc-wide\LS_SPC-20200610_1000.fits
# DEBUG:poppy:OPD: None
# INFO:poppy:Lyot Stop: Loaded amplitude transmission from C:\Users\Kian\Desktop\roman-cgi-phasec-data\spc-wide\LS_SPC-20200610_1000.fits
# DEBUG:poppy:Initialized: Primary, fl =2.84e+00 m
# DEBUG:poppy:Initialized: Secondary, fl =-6.54e-01 m
# DEBUG:poppy:Initialized: M3, fl =4.30e-01 m
# DEBUG:poppy:Initialized: M4, fl =1.16e-01 m
# DEBUG:poppy:Initialized: M5, fl =1.99e-01 m
# DEBUG:poppy:Initialized: OAP1, fl =5.03e-01 m
# DEBUG:poppy:Initialized: OAP2, fl =5.79e-01 m
# DEBUG:poppy:Initialized: OAP3, fl =1.22e+00 m
# DEBUG:poppy:Initialized: OAP4, fl =4.47e-01 m
# DEBUG:poppy:Initialized: OAP5, fl =5.48e-01 m
# DEBUG:poppy:Initialized: OAP6, fl =5.48e-01 m
# DEBUG:poppy:Initialized: OAP7, fl =7.08e-01 m
# DEBUG:poppy:Initialized: OAP8, fl =2.10e-01 m
# DEBUG:poppy:Initialized: LENS 1, fl =1.06e-01 m
# DEBUG:poppy:Initialized: LENS 2, fl =-1.75e-01 m
# INFO:poppy:Initialized OpticalSystem: SPC825
# INFO:poppy:Added optic: Roman Pupil after separation: 0.00e+00 m
# INFO:poppy:Added optic: Primary after separation: 0.00e+00 m
# INFO:poppy:Added optic: Secondary after separation: 2.29e+00 m
# INFO:poppy:Added optic: POMA Fold after separation: 2.99e+00 m
# INFO:poppy:Added optic: M3 after separation: 1.68e+00 m
# INFO:poppy:Added optic: M4 after separation: 9.44e-01 m
# INFO:poppy:Added optic: M5 after separation: 4.29e-01 m
# INFO:poppy:Added optic: TT Fold after separation: 3.51e-01 m
# INFO:poppy:Added optic: FSM after separation: 3.65e-01 m
# INFO:poppy:Added optic: OAP1 after separation: 3.55e-01 m
# INFO:poppy:Added optic: FOCM after separation: 7.68e-01 m
# INFO:poppy:Added optic: OAP2 after separation: 3.15e-01 m
# INFO:poppy:Added optic: DM1 Plane (No Optic) after separation: 7.76e-01 m
# INFO:poppy:Added optic: DM2 Plane (No Optic) after separation: 1.00e+00 m
# INFO:poppy:Added optic: OAP3 after separation: 3.95e-01 m
# INFO:poppy:Added optic: Fold 3 after separation: 5.05e-01 m
# INFO:poppy:Added optic: OAP4 after separation: 1.16e+00 m
# INFO:poppy:Added optic: SPM after separation: 4.23e-01 m
# INFO:poppy:Added optic: OAP5 after separation: 4.09e-01 m
# INFO:poppy:Added optic: FPM after separation: 5.48e-01 m
# INFO:poppy:Added optic: OAP6 after separation: 5.48e-01 m
# INFO:poppy:Added optic: Lyot Stop after separation: 6.87e-01 m
# INFO:poppy:Added optic: OAP7 after separation: 4.02e-01 m
# INFO:poppy:Added optic: Field Stop Plane (No Optic) after separation: 7.08e-01 m
# INFO:poppy:Added optic: OAP8 after separation: 2.10e-01 m
# INFO:poppy:Added optic: Filter after separation: 3.68e-01 m
# INFO:poppy:Added optic: LENS 1 after separation: 2.14e-01 m
# INFO:poppy:Added optic: LENS 2 after separation: 3.05e-03 m
# INFO:poppy:Added optic: Fold 4 after separation: 2.02e-01 m
# INFO:poppy:Added optic: focus after separation: 5.00e-02 m
# DEBUG:poppy:Padded WF array for oversampling by 2.048, to (2048, 2048).
# Not employing polarization aberrations.
# INFO:poppy:Calculating PSF with 1 wavelengths
# INFO:poppy:User requested saving intermediate wavefronts in call to poppy.calc_psf
# DEBUG:poppy:Trying to reload wisdom from file C:\Users\Kian\.astropy\config\poppy_fftw_wisdom.json
# DEBUG:poppy:Reloaded double precision wisdom: True
# DEBUG:poppy:Reloaded single precision wisdom: True
# DEBUG:poppy:Reloaded longdouble precision wisdom: False
# DEBUG:poppy:Reloaded _FFTW_INIT list of optimized array sizes
# INFO:poppy: Propagating wavelength = 8.25e-07 m
# INFO:poppy:Using user-defined FresnelWavefront() for the input wavefront of the FresnelOpticalSystem().
# DEBUG:poppy:Input wavefront has wavelength=0.8250000000000001 microns, npix=1000, diam=2.363114 m, pixel scale=0.002363114 m / pix
# DEBUG:poppy:  Propagating wavefront to Pupil plane: Roman Pupil  after distance 0.0 m
# DEBUG:poppy:Array shape (1001, 1001) is smaller than desired shape [2048, 2048]; will attempt to zero-pad the array
# DEBUG:poppy:  Padded with a 523 x 523 border to  match the desired shape
# DEBUG:poppy:  Multiplied WF by phasor for Pupil plane: Roman Pupil
# DEBUG:poppy:normalizing at first plane (entrance pupil) to 1.0 total intensity
# DEBUG:poppy:  Propagating wavefront to Lens: Primary, with focal length 2.83827920690472 m after distance 0.0 m
# DEBUG:poppy:------ Applying Lens: Primary ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:1.182e+00 m, z_w0=0.000e+00 m
# z=0.000e+00 m, z_r=5.316e+06 m
# DEBUG:poppy:  Beam radius at Primary =1.18e+00 m
# DEBUG:poppy: input flat wavefront and Primary has output beam curvature of =-2.84e+00 m
# DEBUG:poppy:Primary has a curvature of =-2.84e+00 m
# DEBUG:poppy:Primary has a curved output wavefront, with waist at 2.838279206903911 m
# DEBUG:poppy:Post Optic Parameters:w_0:6.308e-07 m, z_w0=2.838e+00 m
# z=0.000e+00 m, z_r=1.515e-06 m
# DEBUG:poppy:Set output beam focal length to 2.83827920690472 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =9.96e+12 m
# DEBUG:poppy:Applying spherical lens phase =1.00e-13 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Primary
# DEBUG:poppy:------ Optic: Primary applied ------
# DEBUG:poppy:  Propagating wavefront to Lens: Secondary, with focal length -0.654200796568004 m after distance 2.285150508110035 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 2.838279206903911 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 0.002363114 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=2.838279206903911 m
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.156927 s, full function  in 0.161 s
# DEBUG:poppy:Applying spherical phase curvature =2.84e+00 m
# DEBUG:poppy:Applying spherical lens phase =3.52e-01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 4.838318329846725e-07 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=-0.5531286987938757 m
# DEBUG:poppy:Applying spherical phase curvature =-5.53e-01 m
# DEBUG:poppy:Applying spherical lens phase =-1.81e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.036530 s, full function  in 0.041 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 2.29e+00 m ------
# DEBUG:poppy:------ Applying Lens: Secondary ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:6.308e-07 m, z_w0=2.838e+00 m
# z=2.285e+00 m, z_r=1.515e-06 m
# DEBUG:poppy:  Beam radius at Secondary =2.30e-01 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:6.308e-07 m, z_w0=2.838e+00 m
# z=2.285e+00 m, z_r=1.515e-06 m
# DEBUG:poppy: input curved wavefront and Secondary has output beam curvature of =-3.58e+00 m
# DEBUG:poppy:Secondary has a curvature of =-3.58e+00 m
# DEBUG:poppy:Secondary has a curved output wavefront, with waist at 5.865339731727833 m
# DEBUG:poppy:Post Optic Parameters:w_0:4.083e-06 m, z_w0=5.865e+00 m
# z=2.285e+00 m, z_r=6.348e-05 m
# DEBUG:poppy:Magnification: 6.472615202484119  from R_in = -0.5531286987938757 m, R_out = -3.5801892247434988 m
# DEBUG:poppy:Output beam focal length is now 18.371089143506058 m
# DEBUG:poppy:Spherical to Spherical wavefront propagation.
# DEBUG:poppy:1/fl=-1.5286e+00 1 / m
# DEBUG:poppy:1.0/(R_input_beam)=-1.8079e+00 1 / m
# DEBUG:poppy:1.0/(self.z-self.z_w0)=-2.7931e-01 1 / m
# DEBUG:poppy:Applying spherical phase curvature =1.35e+10 m
# DEBUG:poppy:Applying spherical lens phase =7.43e-11 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Secondary
# DEBUG:poppy:------ Optic: Secondary applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: POMA Fold after distance 2.993753469304728 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 5.865339731727833 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 0.0004605276918289606 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=3.5801892236177975 m
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.037031 s, full function  in 0.042 s
# DEBUG:poppy:Applying spherical phase curvature =3.58e+00 m
# DEBUG:poppy:Applying spherical lens phase =2.79e-01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 3.131657276637676e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=-0.5864357543130696 m
# DEBUG:poppy:Applying spherical phase curvature =-5.86e-01 m
# DEBUG:poppy:Applying spherical lens phase =-1.71e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.041034 s, full function  in 0.045 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 5.28e+00 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: POMA Fold
# DEBUG:poppy:  Propagating wavefront to Lens: M3, with focal length 0.430216463069001 m after distance 1.680935841598811 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 5.865339731727833 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 7.54345336157586e-05 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.5864357543130696 m
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.036030 s, full function  in 0.041 s
# DEBUG:poppy:Applying spherical phase curvature =5.86e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.71e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 3.1316572766376757e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=1.0945000872857413 m
# DEBUG:poppy:Applying spherical phase curvature =1.09e+00 m
# DEBUG:poppy:Applying spherical lens phase =9.14e-01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.035028 s, full function  in 0.040 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 6.96e+00 m ------
# DEBUG:poppy:------ Applying Lens: M3 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:4.083e-06 m, z_w0=5.865e+00 m
# z=6.960e+00 m, z_r=6.348e-05 m
# DEBUG:poppy:  Beam radius at M3 =7.04e-02 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:4.083e-06 m, z_w0=5.865e+00 m
# z=6.960e+00 m, z_r=6.348e-05 m
# DEBUG:poppy: input curved wavefront and M3 has output beam curvature of =-7.09e-01 m
# DEBUG:poppy:M3 has a curvature of =-7.09e-01 m
# DEBUG:poppy:M3 has a curved output wavefront, with waist at 7.668681550955357 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.644e-06 m, z_w0=7.669e+00 m
# z=6.960e+00 m, z_r=2.663e-05 m
# DEBUG:poppy:Magnification: -0.6476397226243326  from R_in = 1.0945000872857413 m, R_out = -0.7088417329420453 m
# DEBUG:poppy:Output beam focal length is now -11.897847077207151 m
# DEBUG:poppy:Spherical to Spherical wavefront propagation.
# DEBUG:poppy:1/fl=2.3244e+00 1 / m
# DEBUG:poppy:1.0/(R_input_beam)=9.1366e-01 1 / m
# DEBUG:poppy:1.0/(self.z-self.z_w0)=-1.4108e+00 1 / m
# DEBUG:poppy:Applying spherical phase curvature =1.97e+08 m
# DEBUG:poppy:Applying spherical lens phase =5.06e-09 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: M3
# DEBUG:poppy:------ Optic: M3 applied ------
# DEBUG:poppy:  Propagating wavefront to Lens: M4, with focal length 0.11623911483359 m after distance 0.943514749358944 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 7.668681550955357 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 0.0001407879772329341 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.7088417319417832 m
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.035529 s, full function  in 0.039 s
# DEBUG:poppy:Applying spherical phase curvature =7.09e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.41e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 2.02818564713408e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=0.23467301741716096 m
# DEBUG:poppy:Applying spherical phase curvature =2.35e-01 m
# DEBUG:poppy:Applying spherical lens phase =4.26e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.038530 s, full function  in 0.043 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 7.90e+00 m ------
# DEBUG:poppy:------ Applying Lens: M4 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:2.644e-06 m, z_w0=7.669e+00 m
# z=7.903e+00 m, z_r=2.663e-05 m
# DEBUG:poppy:  Beam radius at M4 =2.33e-02 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:2.644e-06 m, z_w0=7.669e+00 m
# z=7.903e+00 m, z_r=2.663e-05 m
# DEBUG:poppy: input curved wavefront and M4 has output beam curvature of =-2.30e-01 m
# DEBUG:poppy:M4 has a curvature of =-2.30e-01 m
# DEBUG:poppy:M4 has a curved output wavefront, with waist at 8.133678677785854 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.595e-06 m, z_w0=8.134e+00 m
# z=7.903e+00 m, z_r=2.565e-05 m
# DEBUG:poppy:Magnification: -0.9814682352695353  from R_in = 0.23467301741716096 m, R_out = -0.23032411226979788 m
# DEBUG:poppy:Output beam focal length is now 11.677358974373302 m
# DEBUG:poppy:Spherical to Spherical wavefront propagation.
# DEBUG:poppy:1/fl=8.6030e+00 1 / m
# DEBUG:poppy:1.0/(R_input_beam)=4.2612e+00 1 / m
# DEBUG:poppy:1.0/(self.z-self.z_w0)=-4.3417e+00 1 / m
# DEBUG:poppy:Applying spherical phase curvature =9.20e+06 m
# DEBUG:poppy:Applying spherical lens phase =1.09e-07 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: M4
# DEBUG:poppy:------ Optic: M4 applied ------
# DEBUG:poppy:  Propagating wavefront to Lens: M5, with focal length 0.198821518772608 m after distance 0.429145636743193 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 8.133678677785854 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 4.66100371133689e-05 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.2303241094133357 m
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.061050 s, full function  in 0.072 s
# DEBUG:poppy:Applying spherical phase curvature =2.30e-01 m
# DEBUG:poppy:Applying spherical lens phase =4.34e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 1.990599763204418e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=0.1988215273298568 m
# DEBUG:poppy:Applying spherical phase curvature =1.99e-01 m
# DEBUG:poppy:Applying spherical lens phase =5.03e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.036029 s, full function  in 0.041 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 8.33e+00 m ------
# DEBUG:poppy:------ Applying Lens: M5 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:2.595e-06 m, z_w0=8.134e+00 m
# z=8.333e+00 m, z_r=2.565e-05 m
# DEBUG:poppy:  Beam radius at M5 =2.01e-02 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:2.595e-06 m, z_w0=8.134e+00 m
# z=8.333e+00 m, z_r=2.565e-05 m
# DEBUG:poppy: input curved wavefront and M5 has output beam curvature of =-3.33e+06 m
# DEBUG:poppy:M5 has a curvature of =-3.33e+06 m
# DEBUG:poppy:M5 has a curved output wavefront, with waist at 9.045475401071503 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.012e-02 m, z_w0=9.045e+00 m
# z=8.333e+00 m, z_r=1.541e+03 m
# DEBUG:poppy:Magnification: -16755129.063052176  from R_in = 0.1988215273298568 m, R_out = -3331280.3509249063 m
# DEBUG:poppy:Output beam focal length is now -195655656.73121527 m
# DEBUG:poppy:Spherical to Planar.
# DEBUG:poppy:Applying spherical phase curvature =-4.62e+06 m
# DEBUG:poppy:Applying spherical lens phase =-2.16e-07 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: M5
# DEBUG:poppy:------ Optic: M5 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: TT Fold after distance 0.35112543122077 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 9.045475401071503 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.35112543122077 m
# DEBUG:poppy:  Constant Pixelscale: 4.0234948878715836e-05 m / pix
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.035029 s, full function  in 0.040 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.035528 s, full function  in 0.040 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 8.68e+00 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: TT Fold
# DEBUG:poppy:  Propagating wavefront to Optic: FSM after distance 0.365403811707006 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 9.045475401071503 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.365403811707006 m
# DEBUG:poppy:  Constant Pixelscale: 4.0234948878715836e-05 m / pix
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.035529 s, full function  in 0.040 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.035028 s, full function  in 0.040 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 9.05e+00 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: FSM
# DEBUG:poppy:  Propagating wavefront to Lens: OAP1, with focal length 0.503331895563883 m after distance 0.354826767220001 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 9.045475401071503 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.354826767220001 m
# DEBUG:poppy:  Constant Pixelscale: 4.0234948878715836e-05 m / pix
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.059048 s, full function  in 0.070 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.043535 s, full function  in 0.050 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 9.40e+00 m ------
# DEBUG:poppy:------ Applying Lens: OAP1 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:2.012e-02 m, z_w0=9.045e+00 m
# z=9.404e+00 m, z_r=1.541e+03 m
# DEBUG:poppy:  Beam radius at OAP1 =2.01e-02 m
# DEBUG:poppy: input flat wavefront and OAP1 has output beam curvature of =-5.03e-01 m
# DEBUG:poppy:OAP1 has a curvature of =-5.03e-01 m
# DEBUG:poppy:OAP1 has a curved output wavefront, with waist at 9.907188057139306 m
# DEBUG:poppy:Post Optic Parameters:w_0:6.570e-06 m, z_w0=9.907e+00 m
# z=9.404e+00 m, z_r=1.644e-04 m
# DEBUG:poppy:Magnification: -0.0  from R_in = inf m, R_out = -0.503331895563883 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =4.72e+06 m
# DEBUG:poppy:Applying spherical lens phase =2.12e-07 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP1
# DEBUG:poppy:------ Optic: OAP1 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: FOCM after distance 0.768029932093727 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 9.907188057139306 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 4.0234948878715836e-05 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.5033318418758181 m
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.035028 s, full function  in 0.039 s
# DEBUG:poppy:Applying spherical phase curvature =5.03e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.99e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 5.039354936595883e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=0.2646980902179088 m
# DEBUG:poppy:Applying spherical phase curvature =2.65e-01 m
# DEBUG:poppy:Applying spherical lens phase =3.78e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.035529 s, full function  in 0.040 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.02e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: FOCM
# DEBUG:poppy:  Propagating wavefront to Lens: OAP2, with focal length 0.57920557125499 m after distance 0.314507535543064 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 9.907188057139306 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 2.1159229840338346e-05 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=-0.2646980902179088 m
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.036029 s, full function  in 0.040 s
# DEBUG:poppy:Applying spherical phase curvature =-2.65e-01 m
# DEBUG:poppy:Applying spherical lens phase =-3.78e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 5.039354936595883e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=0.5792056257609719 m
# DEBUG:poppy:Applying spherical phase curvature =5.79e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.73e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.035028 s, full function  in 0.039 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.05e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP2 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:6.570e-06 m, z_w0=9.907e+00 m
# z=1.049e+01 m, z_r=1.644e-04 m
# DEBUG:poppy:  Beam radius at OAP2 =2.32e-02 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:6.570e-06 m, z_w0=9.907e+00 m
# z=1.049e+01 m, z_r=1.644e-04 m
# DEBUG:poppy: input curved wavefront and OAP2 has output beam curvature of =-3.32e+06 m
# DEBUG:poppy:OAP2 has a curvature of =-3.32e+06 m
# DEBUG:poppy:OAP2 has a curved output wavefront, with waist at 11.742270035659718 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.315e-02 m, z_w0=1.174e+01 m
# z=1.049e+01 m, z_r=2.041e+03 m
# DEBUG:poppy:Magnification: -5725575.948672015  from R_in = 0.5792056257609719 m, R_out = -3316285.8001925447 m
# DEBUG:poppy:Output beam focal length is now -0.0 m
# DEBUG:poppy:Spherical to Planar.
# DEBUG:poppy:Applying spherical phase curvature =-6.15e+06 m
# DEBUG:poppy:Applying spherical lens phase =-1.62e-07 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP2
# DEBUG:poppy:------ Optic: OAP2 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: DM1 Plane (No Optic) after distance 0.775857408587825 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 11.742270035659718 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.775857408587825 m
# DEBUG:poppy:  Constant Pixelscale: 4.630008833914972e-05 m / pix
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.034528 s, full function  in 0.039 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.034028 s, full function  in 0.039 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.13e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: DM1 Plane (No Optic)
# DEBUG:poppy:  Propagating wavefront to Optic: DM2 Plane (No Optic) after distance 1.0 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 11.742270035659718 m
# DEBUG:poppy:  Plane to Plane Regime, dz=1.0 m
# DEBUG:poppy:  Constant Pixelscale: 4.630008833914972e-05 m / pix
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.036530 s, full function  in 0.041 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.035529 s, full function  in 0.039 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.23e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: DM2 Plane (No Optic)
# DEBUG:poppy:  Propagating wavefront to Lens: OAP3, with focal length 1.217276467668519 m after distance 0.394833855161549 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 11.742270035659718 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.394833855161549 m
# DEBUG:poppy:  Constant Pixelscale: 4.630008833914972e-05 m / pix
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.035529 s, full function  in 0.040 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.036530 s, full function  in 0.041 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.27e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP3 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:2.315e-02 m, z_w0=1.174e+01 m
# z=1.266e+01 m, z_r=2.041e+03 m
# DEBUG:poppy:  Beam radius at OAP3 =2.32e-02 m
# DEBUG:poppy: input flat wavefront and OAP3 has output beam curvature of =-1.22e+00 m
# DEBUG:poppy:OAP3 has a curvature of =-1.22e+00 m
# DEBUG:poppy:OAP3 has a curved output wavefront, with waist at 13.87436098123762 m
# DEBUG:poppy:Post Optic Parameters:w_0:1.381e-05 m, z_w0=1.387e+01 m
# z=1.266e+01 m, z_r=7.261e-04 m
# DEBUG:poppy:Magnification: -0.0  from R_in = inf m, R_out = -1.217276467668519 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =3.42e+06 m
# DEBUG:poppy:Applying spherical lens phase =2.92e-07 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP3
# DEBUG:poppy:------ Optic: OAP3 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: Fold 3 after distance 0.505329955078121 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 13.87436098123762 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 4.630008833914972e-05 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=1.217276034587968 m
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.035029 s, full function  in 0.040 s
# DEBUG:poppy:Applying spherical phase curvature =1.22e+00 m
# DEBUG:poppy:Applying spherical lens phase =8.22e-01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 1.0590860518734415e-05 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=-0.7119460795098469 m
# DEBUG:poppy:Applying spherical phase curvature =-7.12e-01 m
# DEBUG:poppy:Applying spherical lens phase =-1.40e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.035530 s, full function  in 0.040 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.32e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Fold 3
# DEBUG:poppy:  Propagating wavefront to Lens: OAP4, with focal length 0.446951159052363 m after distance 1.158897671642761 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 13.87436098123762 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 2.707945070583339e-05 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.7119460795098469 m
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.039033 s, full function  in 0.045 s
# DEBUG:poppy:Applying spherical phase curvature =7.12e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.40e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 1.0590860518734415e-05 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=0.4469515921329137 m
# DEBUG:poppy:Applying spherical phase curvature =4.47e-01 m
# DEBUG:poppy:Applying spherical lens phase =2.24e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.035529 s, full function  in 0.040 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.43e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP4 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:1.381e-05 m, z_w0=1.387e+01 m
# z=1.432e+01 m, z_r=7.261e-04 m
# DEBUG:poppy:  Beam radius at OAP4 =8.50e-03 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:1.381e-05 m, z_w0=1.387e+01 m
# z=1.432e+01 m, z_r=7.261e-04 m
# DEBUG:poppy: input curved wavefront and OAP4 has output beam curvature of =-1.24e+05 m
# DEBUG:poppy:OAP4 has a curvature of =-1.24e+05 m
# DEBUG:poppy:OAP4 has a curved output wavefront, with waist at 14.932372169620972 m
# DEBUG:poppy:Post Optic Parameters:w_0:8.500e-03 m, z_w0=1.493e+01 m
# z=1.432e+01 m, z_r=2.751e+02 m
# DEBUG:poppy:Magnification: -277166.2176794143  from R_in = 0.4469515921329137 m, R_out = -123879.88227727196 m
# DEBUG:poppy:Output beam focal length is now -0.0 m
# DEBUG:poppy:Spherical to Planar.
# DEBUG:poppy:Applying spherical phase curvature =-4.61e+05 m
# DEBUG:poppy:Applying spherical lens phase =-2.17e-06 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP4
# DEBUG:poppy:------ Optic: OAP4 applied ------
# DEBUG:poppy:  Propagating wavefront to Pupil plane: SPM  after distance 0.423013568764728 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 14.932372169620972 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.423013568764728 m
# DEBUG:poppy:  Constant Pixelscale: 1.700016891081088e-05 m / pix
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.035028 s, full function  in 0.039 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.035029 s, full function  in 0.039 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.47e+01 m ------
# DEBUG:poppy:Array shape (1001, 1001) is smaller than desired shape [2048, 2048]; will attempt to zero-pad the array
# DEBUG:poppy:  Padded with a 523 x 523 border to  match the desired shape
# DEBUG:poppy:  Multiplied WF by phasor for Pupil plane: SPM
# DEBUG:poppy:  Propagating wavefront to Lens: OAP5, with focal length 0.548189354706822 m after distance 0.408810704327559 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 14.932372169620972 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.408810704327559 m
# DEBUG:poppy:  Constant Pixelscale: 1.700016891081088e-05 m / pix
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.036029 s, full function  in 0.040 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.034529 s, full function  in 0.045 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.52e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP5 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:8.500e-03 m, z_w0=1.493e+01 m
# z=1.515e+01 m, z_r=2.751e+02 m
# DEBUG:poppy:  Beam radius at OAP5 =8.50e-03 m
# DEBUG:poppy: input flat wavefront and OAP5 has output beam curvature of =-5.48e-01 m
# DEBUG:poppy:OAP5 has a curvature of =-5.48e-01 m
# DEBUG:poppy:OAP5 has a curved output wavefront, with waist at 15.701324024927084 m
# DEBUG:poppy:Post Optic Parameters:w_0:1.694e-05 m, z_w0=1.570e+01 m
# z=1.515e+01 m, z_r=1.092e-03 m
# DEBUG:poppy:Magnification: -0.0  from R_in = inf m, R_out = -0.548189354706822 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =1.38e+05 m
# DEBUG:poppy:Applying spherical lens phase =7.24e-06 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP5
# DEBUG:poppy:------ Optic: OAP5 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: FPM after distance 0.548189354706822 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 15.701324024927084 m
# DEBUG:poppy:  Spherical to Plane Regime, outside Z_R to inside Z_R
# DEBUG:poppy:Spherical to Waist propagation, dz=0.5481871784642625 m
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.036531 s, full function  in 0.041 s
# DEBUG:poppy:Applying spherical phase curvature =5.48e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.82e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.036030 s, full function  in 0.040 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.035529 s, full function  in 0.040 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.57e+01 m ------
# DEBUG:poppy:------ Applying FixedSamplingImagePlaneElement using FFT and MFT sequence ------
# DEBUG:poppy:Calculating FPM phasor from numexpr.
# DEBUG:poppy:MatrixFourierTransform initialized using centering type = ADJUSTABLE
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.041534 s, full function  in 0.064 s
# DEBUG:poppy:Forward MatrixFourierTransform: array shape (2048, 2048), centering style ADJUSTABLE, output region size 84.17280000000001 in lambda / D units, output array size 411 pixels, offset None
# DEBUG:poppy:Inverse MatrixFourierTransform: array shape (411, 411), centering style ADJUSTABLE, output region size 84.17280000000001 in lambda / D units, output array size 2048 pixels, offset None
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.038032 s, full function  in 0.061 s
# DEBUG:poppy:------ FixedSamplingImagePlaneElement: FPM applied ------
# DEBUG:poppy:  Propagating wavefront to Lens: OAP6, with focal length 0.5481466704471673 m after distance 0.5481466704471673 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 15.701324024927084 m
# DEBUG:poppy:  Plane to Spherical Regime, inside Z_R to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 1.2989715323683335e-05 m / pix
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.035529 s, full function  in 0.040 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.034527 s, full function  in 0.039 s
# DEBUG:poppy:Waist to Spherical propagation, dz=0.5481488466897257 m
# DEBUG:poppy:Applying spherical phase curvature =5.48e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.82e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.036530 s, full function  in 0.041 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.62e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP6 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:1.694e-05 m, z_w0=1.570e+01 m
# z=1.625e+01 m, z_r=1.092e-03 m
# DEBUG:poppy:  Beam radius at OAP6 =8.50e-03 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:1.694e-05 m, z_w0=1.570e+01 m
# z=1.625e+01 m, z_r=1.092e-03 m
# DEBUG:poppy: input curved wavefront and OAP6 has output beam curvature of =-6.90e+04 m
# DEBUG:poppy:OAP6 has a curvature of =-6.90e+04 m
# DEBUG:poppy:OAP6 has a curved output wavefront, with waist at 17.3457235312795 m
# DEBUG:poppy:Post Optic Parameters:w_0:8.499e-03 m, z_w0=1.735e+01 m
# z=1.625e+01 m, z_r=2.751e+02 m
# DEBUG:poppy:Magnification: -125934.87783233229  from R_in = 0.5481488466897257 m, R_out = -69031.05804180446 m
# DEBUG:poppy:Output beam focal length is now -0.0 m
# DEBUG:poppy:Spherical to Planar.
# DEBUG:poppy:Applying spherical phase curvature =-1.38e+05 m
# DEBUG:poppy:Applying spherical lens phase =-7.24e-06 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP6
# DEBUG:poppy:------ Optic: OAP6 applied ------
# DEBUG:poppy:  Propagating wavefront to Pupil plane: Lyot Stop  after distance 0.687476361491529 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 17.3457235312795 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.687476361491529 m
# DEBUG:poppy:  Constant Pixelscale: 1.6998980180633716e-05 m / pix
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.035528 s, full function  in 0.040 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.038531 s, full function  in 0.043 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.69e+01 m ------
# DEBUG:poppy:Array shape (1001, 1001) is smaller than desired shape [2048, 2048]; will attempt to zero-pad the array
# DEBUG:poppy:  Padded with a 523 x 523 border to  match the desired shape
# DEBUG:poppy:  Multiplied WF by phasor for Pupil plane: Lyot Stop
# DEBUG:poppy:  Propagating wavefront to Lens: OAP7, with focal length 0.70825142092381 m after distance 0.401748561745987 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 17.3457235312795 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.401748561745987 m
# DEBUG:poppy:  Constant Pixelscale: 1.6998980180633716e-05 m / pix
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.036029 s, full function  in 0.041 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.035028 s, full function  in 0.040 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.73e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP7 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:8.499e-03 m, z_w0=1.735e+01 m
# z=1.734e+01 m, z_r=2.751e+02 m
# DEBUG:poppy:  Beam radius at OAP7 =8.50e-03 m
# DEBUG:poppy: input flat wavefront and OAP7 has output beam curvature of =-7.08e-01 m
# DEBUG:poppy:OAP7 has a curvature of =-7.08e-01 m
# DEBUG:poppy:OAP7 has a curved output wavefront, with waist at 18.046944521033403 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.188e-05 m, z_w0=1.805e+01 m
# z=1.734e+01 m, z_r=1.823e-03 m
# DEBUG:poppy:Magnification: -0.0  from R_in = inf m, R_out = -0.70825142092381 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =1.07e+05 m
# DEBUG:poppy:Applying spherical lens phase =9.36e-06 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP7
# DEBUG:poppy:------ Optic: OAP7 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: Field Stop Plane (No Optic) after distance 0.70825142092381 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 18.046944521033403 m
# DEBUG:poppy:  Spherical to Plane Regime, outside Z_R to inside Z_R
# DEBUG:poppy:Spherical to Waist propagation, dz=0.7082467261790768 m
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.035028 s, full function  in 0.039 s
# DEBUG:poppy:Applying spherical phase curvature =7.08e-01 m
# DEBUG:poppy:Applying spherical lens phase =1.41e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.035029 s, full function  in 0.040 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.034527 s, full function  in 0.039 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.80e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Field Stop Plane (No Optic)
# DEBUG:poppy:  Propagating wavefront to Lens: OAP8, with focal length 0.2104895661807894 m after distance 0.2104895661807894 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 18.046944521033403 m
# DEBUG:poppy:  Plane to Spherical Regime, inside Z_R to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 1.6783622564482807e-05 m / pix
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.034528 s, full function  in 0.039 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.036030 s, full function  in 0.041 s
# DEBUG:poppy:Waist to Spherical propagation, dz=0.21049426092552181 m
# DEBUG:poppy:Applying spherical phase curvature =2.10e-01 m
# DEBUG:poppy:Applying spherical lens phase =4.75e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.038031 s, full function  in 0.044 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.83e+01 m ------
# DEBUG:poppy:------ Applying Lens: OAP8 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:2.188e-05 m, z_w0=1.805e+01 m
# z=1.826e+01 m, z_r=1.823e-03 m
# DEBUG:poppy:  Beam radius at OAP8 =2.53e-03 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:2.188e-05 m, z_w0=1.805e+01 m
# z=1.826e+01 m, z_r=1.823e-03 m
# DEBUG:poppy: input curved wavefront and OAP8 has output beam curvature of =-2.16e+03 m
# DEBUG:poppy:OAP8 has a curvature of =-2.16e+03 m
# DEBUG:poppy:OAP8 has a curved output wavefront, with waist at 18.530485028089128 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.526e-03 m, z_w0=1.853e+01 m
# z=1.826e+01 m, z_r=2.430e+01 m
# DEBUG:poppy:Magnification: -10273.025055857292  from R_in = 0.21049426092552181 m, R_out = -2162.412816602048 m
# DEBUG:poppy:Output beam focal length is now -0.0 m
# DEBUG:poppy:Spherical to Planar.
# DEBUG:poppy:Applying spherical phase curvature =-9.44e+03 m
# DEBUG:poppy:Applying spherical lens phase =-1.06e-04 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: OAP8
# DEBUG:poppy:------ Optic: OAP8 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: Filter after distance 0.36756158767400804 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 18.530485028089128 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.36756158767400804 m
# DEBUG:poppy:  Constant Pixelscale: 5.052176928390573e-06 m / pix
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.034528 s, full function  in 0.039 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.035028 s, full function  in 0.040 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.86e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Filter
# DEBUG:poppy:  Propagating wavefront to Lens: LENS 1, with focal length 0.10634603992822719 m after distance 0.21434365249697815 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 18.530485028089128 m
# DEBUG:poppy:  Plane to Plane Regime, dz=0.21434365249697815 m
# DEBUG:poppy:  Constant Pixelscale: 5.052176928390573e-06 m / pix
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.034528 s, full function  in 0.040 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.035530 s, full function  in 0.040 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.88e+01 m ------
# DEBUG:poppy:------ Applying Lens: LENS 1 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:2.526e-03 m, z_w0=1.853e+01 m
# z=1.884e+01 m, z_r=2.430e+01 m
# DEBUG:poppy:  Beam radius at LENS 1 =2.53e-03 m
# DEBUG:poppy: input flat wavefront and LENS 1 has output beam curvature of =-1.06e-01 m
# DEBUG:poppy:LENS 1 has a curvature of =-1.06e-01 m
# DEBUG:poppy:LENS 1 has a curved output wavefront, with waist at 18.945688025506925 m
# DEBUG:poppy:Post Optic Parameters:w_0:1.105e-05 m, z_w0=1.895e+01 m
# z=1.884e+01 m, z_r=4.654e-04 m
# DEBUG:poppy:Magnification: -0.0  from R_in = inf m, R_out = -0.10634603992822719 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Inside Rayleigh distance to Outside Rayleigh distance.
# DEBUG:poppy:Applying spherical phase curvature =5.55e+03 m
# DEBUG:poppy:Applying spherical lens phase =1.80e-04 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: LENS 1
# DEBUG:poppy:------ Optic: LENS 1 applied ------
# DEBUG:poppy:  Propagating wavefront to Lens: LENS 2, with focal length -0.1745980157558932 m after distance 0.0030533019231360065 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 18.945688025506925 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 5.052176928390573e-06 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.10634400337701422 m
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.040033 s, full function  in 0.046 s
# DEBUG:poppy:Applying spherical phase curvature =1.06e-01 m
# DEBUG:poppy:Applying spherical lens phase =9.40e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 8.479269728438879e-06 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=-0.10329070145387931 m
# DEBUG:poppy:Applying spherical phase curvature =-1.03e-01 m
# DEBUG:poppy:Applying spherical lens phase =-9.68e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.035029 s, full function  in 0.040 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.88e+01 m ------
# DEBUG:poppy:------ Applying Lens: LENS 2 ------
# DEBUG:poppy:  Pre-Lens Beam Parameters: w_0:1.105e-05 m, z_w0=1.895e+01 m
# z=1.884e+01 m, z_r=4.654e-04 m
# DEBUG:poppy:  Beam radius at LENS 2 =2.45e-03 m
# DEBUG:poppy:spherical beam
# DEBUG:poppy:w_0:1.105e-05 m, z_w0=1.895e+01 m
# z=1.884e+01 m, z_r=4.654e-04 m
# DEBUG:poppy: input curved wavefront and LENS 2 has output beam curvature of =-2.53e-01 m
# DEBUG:poppy:LENS 2 has a curvature of =-2.53e-01 m
# DEBUG:poppy:LENS 2 has a curved output wavefront, with waist at 19.095289377567564 m
# DEBUG:poppy:Post Optic Parameters:w_0:2.707e-05 m, z_w0=1.910e+01 m
# z=1.884e+01 m, z_r=2.790e-03 m
# DEBUG:poppy:Magnification: 2.448650547779077  from R_in = -0.10329070145387931 m, R_out = -0.2529228326955267 m
# DEBUG:poppy:Output beam focal length is now 0.0 m
# DEBUG:poppy:Spherical to Spherical wavefront propagation.
# DEBUG:poppy:1/fl=-5.7274e+00 1 / m
# DEBUG:poppy:1.0/(R_input_beam)=-9.6814e+00 1 / m
# DEBUG:poppy:1.0/(self.z-self.z_w0)=-3.9543e+00 1 / m
# DEBUG:poppy:Applying spherical phase curvature =3.51e+03 m
# DEBUG:poppy:Applying spherical lens phase =2.85e-04 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: LENS 2
# DEBUG:poppy:------ Optic: LENS 2 applied ------
# DEBUG:poppy:  Propagating wavefront to Optic: Fold 4 after distance 0.2024321556677445 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 19.095289377567564 m
# DEBUG:poppy:  Spherical to Spherical, Outside Z_R to waist (z_w0) to outside Z_R
# DEBUG:poppy:  Starting Pixelscale: 4.907121062129975e-06 m / pix
# DEBUG:poppy:Spherical to Waist propagation, dz=0.25289205351451827 m
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.037031 s, full function  in 0.041 s
# DEBUG:poppy:Applying spherical phase curvature =2.53e-01 m
# DEBUG:poppy:Applying spherical lens phase =3.95e+00 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:  Intermediate Pixelscale: 2.0760241761799597e-05 m / pix
# DEBUG:poppy:Waist to Spherical propagation, dz=-0.05045989784677474 m
# DEBUG:poppy:Applying spherical phase curvature =-5.05e-02 m
# DEBUG:poppy:Applying spherical lens phase =-1.98e+01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.035029 s, full function  in 0.040 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.90e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Fold 4
# DEBUG:poppy:  Propagating wavefront to Optic: focus after distance 0.050000152941020164 m
# DEBUG:poppy:Beginning Fresnel Prop. Waist at z = 19.095289377567564 m
# DEBUG:poppy:  Spherical to Plane Regime, outside Z_R to inside Z_R
# DEBUG:poppy:Spherical to Waist propagation, dz=0.05045989784677474 m
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.036530 s, full function  in 0.041 s
# DEBUG:poppy:Applying spherical phase curvature =5.05e-02 m
# DEBUG:poppy:Applying spherical lens phase =1.98e+01 1 / m
# DEBUG:poppy:  Multiplied WF by phasor for Optic: Quadratic Wavefront Curvature Operator
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=forward
# DEBUG:poppy:    FFT_2D: FFT in 0.039532 s, full function  in 0.044 s
# DEBUG:poppy:using pyopencl (OpenCL GPU) FFT of (2048, 2048) array, FFT_direction=backward
# DEBUG:poppy:    FFT_2D: FFT in 0.036530 s, full function  in 0.041 s
# DEBUG:poppy:------ Propagated to plane of type PlaneType.intermediate at z = 1.91e+01 m ------
# DEBUG:poppy:  Multiplied WF by phasor for Optic: focus
# INFO:poppy:  Calculation completed in 11.408 s
# DEBUG:poppy:FFTW wisdom saved to C:\Users\Kian\.astropy\config\poppy_fftw_wisdom.json
# INFO:poppy:PSF Calculation completed.
# PSF calculated in 12.19s
# FPM pixelscale:  1.2989715323683335e-05 m / pix
# Resampling PSF wavefront to a pixelscale of 0.100 lam/D.
# Input POPPY wavefront pixelscale:  2.0760241761799597e-05 m / pix
# Interpolated POPPY wavefront pixelscale:  4.252458802590218e-06 m / pix

# %%
wfdir=Path('C:/Users/Kian/Desktop/roman-waves/phasec/spc-wide')
cgi.utils.save_waves(wfs, use_opds, use_apertures, wfdir, npix=1000)
# Out:
# Saving wavefronts:
# 0 Saved pupil wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_pupil_poppy.fits
# 1 Saved primary wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_primary_poppy.fits
# 2 Saved secondary wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_secondary_poppy.fits
# 3 Saved pomafold wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_pomafold_poppy.fits
# 4 Saved m3 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_m3_poppy.fits
# 5 Saved m4 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_m4_poppy.fits
# 6 Saved m5 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_m5_poppy.fits
# 7 Saved ttfold wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_ttfold_poppy.fits
# 8 Saved fsm wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_fsm_poppy.fits
# 9 Saved oap1 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_oap1_poppy.fits
# 10 Saved focm wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_focm_poppy.fits
# 11 Saved oap2 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_oap2_poppy.fits
# 12 Saved dm1 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_dm1_poppy.fits
# 13 Saved dm2 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_dm2_poppy.fits
# 14 Saved oap3 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_oap3_poppy.fits
# 15 Saved fold3 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_fold3_poppy.fits
# 16 Saved oap4 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_oap4_poppy.fits
# 17 Saved spm wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_spm_poppy.fits
# 18 Saved oap5 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_oap5_poppy.fits
# 19 Saved fpm wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_fpm_poppy.fits
# 20 Saved oap6 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_oap6_poppy.fits
# 21 Saved lyotstop wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_lyotstop_poppy.fits
# 22 Saved oap7 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_oap7_poppy.fits
# 23 Saved fieldstop wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_fieldstop_poppy.fits
# 24 Saved oap8 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_oap8_poppy.fits
# 25 Saved filter wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_filter_poppy.fits
# 26 Saved lens1 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_lens1_poppy.fits
# 27 Saved lens2 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_lens2_poppy.fits
# 28 Saved fold4 wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_fold4_poppy.fits
# 29 Saved image wavefront to C:\Users\Kian\Desktop\roman-waves\phasec\spc-wide\wf_image_poppy.fits
# All wavefronts saved.

# %%
import proper
import roman_phasec_proper

cor_type = 'spc-wide'
lam_array = np.array([0.825])
# lam_array = np.array([0.770])

n = 512                 # output image dimension (must be power of 2)
final_sampling = 0.1    # output sampling in lam0/D


xoffset = 0
use_fpm = 1
polaxis = 0
use_pupil_defocus = 0

use_errors = 0
use_dms = 0
if use_dms==1: 
    use_dm1 = 1
    use_dm2 = 1
    if cor_type=='spc-spec':
        dm1 = proper.prop_fits_read( roman_phasec_proper.lib_dir + '\\examples\\spc_spec_band3_best_contrast_dm1.fits' )
        dm2 = proper.prop_fits_read( roman_phasec_proper.lib_dir + '\\examples\\spc_spec_band3_best_contrast_dm2.fits' )
        print('Loaded DMs.')
    elif cor_type=='spc-wide':
        dm1 = proper.prop_fits_read( roman_phasec_proper.lib_dir + '\\examples\\spc_wide_band4_best_contrast_dm1.fits' )
        dm2 = proper.prop_fits_read( roman_phasec_proper.lib_dir + '\\examples\\spc_wide_band4_best_contrast_dm2.fits' )
        print('Loaded DMs.')
else: 
    use_dm1 = 0
    use_dm2 = 0
    dm1 = 0
    dm2 = 0
    print('No DMs loaded.')
    
(wfs, wfs_sampling_m) = proper.prop_run_multi('roman_phasec', lam_array, n, QUIET=False, 
                                                PASSVALUE={'cor_type':cor_type,
                                                           'final_sampling_lam0':final_sampling, 
                                                           'source_x_offset':xoffset,
                                                           'use_fpm':use_fpm,
                                                           'use_errors': use_errors,
                                                           'use_pupil_defocus':use_pupil_defocus,
                                                           'use_dm1':use_dm1, 'dm1_m':dm1, 
                                                           'use_dm2':use_dm2, 'dm2_m':dm2,
                                                           'polaxis':polaxis,
                                                          })
proper_psf = wfs[0]
psf_sampling_m = wfs_sampling_m[0]*u.m/u.pix

misc.myimshow2(np.abs(proper_psf)**2, np.angle(proper_psf),
               'PROPER PSF Intensity', 'PROPER PSF Phase',
               pxscl=psf_sampling_m.to(u.mm/u.pix),
               lognorm1=True, cmap1='gist_heat', cmap2='viridis')
# Out:
# No DMs loaded.

# %%
from scipy.ndimage import rotate
from matplotlib.patches import Circle

pop_int = rotate(np.abs(psf)**2, 180)
pop_phs = rotate(np.angle(psf), 180)
prop_int = np.abs(proper_psf)**2
prop_phs = np.angle(proper_psf)

iwa=5.4
owa=20.6
pop_int = misc.mask_psf(pop_int, pixelscale=psf_sampling_m.value, pixelscale_lamD=0.1, iwa=None, owa=owa)
prop_int = misc.mask_psf(prop_int, pixelscale=psf_sampling_m.value, pixelscale_lamD=0.1, iwa=None, owa=owa)

psfs = np.ma.concatenate([pop_int, prop_int])
vmin=np.ma.min(psfs)
vmax=np.ma.max(psfs)
# vmax = 1e-12
vmin = 1e-18


innwa = iwa/final_sampling*psf_sampling_m.value * 1000 # inner and outer working angles in units of m
outwa = owa/final_sampling*psf_sampling_m.value * 1000
patches1 = [Circle((0,0),innwa,edgecolor='c', facecolor='none',lw=1),
            Circle((0,0),outwa,edgecolor='c', facecolor='none',lw=1)]
patches2 = [Circle((0,0),innwa,edgecolor='c', facecolor='none',lw=1),
            Circle((0,0),outwa,edgecolor='c', facecolor='none',lw=1)]
misc.myimshow2(pop_int, prop_int, 'POPPY PSF Intensity', 'PROPER PSF Intensity',
               cmap1='gist_heat', cmap2='gist_heat', 
               lognorm1=True, lognorm2=True, vmin1=vmin, vmax1=vmax, vmin2=vmin, vmax2=vmax,
               pxscl=psf_sampling_m.to(u.mm/u.pix),
               patches1=patches1, patches2=patches2)
patches1 = [Circle((0,0),innwa,edgecolor='c', facecolor='none',lw=1),
            Circle((0,0),outwa,edgecolor='c', facecolor='none',lw=1)]
patches2 = [Circle((0,0),innwa,edgecolor='c', facecolor='none',lw=1),
            Circle((0,0),outwa,edgecolor='c', facecolor='none',lw=1)]
misc.myimshow2(pop_phs, prop_phs, 'POPPY PSF Phase', 'PROPER PSF Phase',
               pxscl=psf_sampling_m.to(u.mm/u.pix),
               cmap1='viridis', cmap2='viridis', patches1=patches1, patches2=patches2)

# Difference
int_diff = np.abs(pop_int-prop_int)
phs_diff = pop_phs-prop_phs
int_diff = pop_int/prop_int
# phs_diff = np.abs(pop_phs/prop_phs)
patches1 = [Circle((0,0),innwa,edgecolor='c', facecolor='none',lw=1),
            Circle((0,0),outwa,edgecolor='c', facecolor='none',lw=1)]
patches2 = [Circle((0,0),innwa,edgecolor='c', facecolor='none',lw=1),
            Circle((0,0),outwa,edgecolor='c', facecolor='none',lw=1)]
misc.myimshow2(int_diff, phs_diff,
               'Intensity Diff', 'Phase Diff',
               pxscl=psf_sampling_m.to(u.mm/u.pix),
               lognorm1=True, 
               vmin1=0.1, vmax1=10, 
#                vmin2=0, vmax2=3,
               cmap1='gist_heat', cmap2='viridis',  
               patches1=patches1, patches2=patches2)
np.ma.mean(int_diff)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d23540a0bf8f> in <module>
#       4 pop_int = rotate(np.abs(psf)**2, 180)
#       5 pop_phs = rotate(np.angle(psf), 180)
# ----> 6 prop_int = np.abs(proper_psf)**2
#       7 prop_phs = np.angle(proper_psf)
#       8
#
# NameError: name 'proper_psf' is not defined
